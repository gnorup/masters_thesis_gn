# %%
import pandas as pd

df = pd.read_csv("/Users/gilanorup/Desktop/Studium/MSc/MA/dataset/combined_audio_durations.csv")

print("more than 5min:", (df["cookieTheft"] > 300).sum())
print("less than 1min:", (df["cookieTheft"] < 60).sum())
print("less than 45s:", (df["cookieTheft"] < 45).sum())
print("less than 30s:", (df["cookieTheft"] < 30).sum())
# Out:
# more than 5min: 1
# less than 1min: 169
# less than 45s: 108
# less than 30s: 40

# %%
print("more than 5min:", (df["picnicScene"] > 300).sum())
print("less than 1min:", (df["picnicScene"] < 60).sum())
print("less than 45s:", (df["picnicScene"] < 45).sum())
print("less than 30s:", (df["picnicScene"] < 30).sum())
# Out:
# more than 5min: 8
# less than 1min: 75
# less than 45s: 38
# less than 30s: 6

# %%
print("more than 5min:", (df["journaling"] > 300).sum())
print("less than 1min:", (df["journaling"] < 60).sum())
print("less than 45s:", (df["journaling"] < 45).sum())
print("less than 30s:", (df["journaling"] < 30).sum())
# Out:
# more than 5min: 10
# less than 1min: 35
# less than 45s: 7
# less than 30s: 3
