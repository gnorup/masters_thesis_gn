# %% [markdown]
# calculate linguistic and acoustic features across all three spontaneous speech tasks (cookieTheft, picnicScene and journaling)
#
# (baut z.T. auf Petti et al., 2023 auf: wie viel Sprache braucht es? -> Idee für später: vergleichen zw. allen tasks, einzelnen tasks und Schnitt aus tasks)

# %%
# setup

import sys

# add the root of the project to the path
sys.path.append("/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/src")

import os
import pandas as pd
from pydub import AudioSegment

from feature_extraction.features import (
    n_words, clean_text, tokenize, pos_ratios_spacy, filler_word_ratio,
    ttr, mattr, avg_word_length,
    light_verb_ratio, empty_word_ratio, nid_ratio, adjacent_repetitions,
    brunets_index, honores_statistic, guirauds_statistic
)

from feature_extraction.features.psycholinguistic_features import (
    compute_avg_by_pos, load_aoa_lexicon, load_imageability_norms,
    load_familiarity_norms, load_frequency_norms, load_concreteness_lexicon
)
from feature_extraction.features.fluency_features import filled_pause_ratio, calculate_fluency_features

from feature_extraction.audio import (count_phonemes, VoiceActivityDetector)
from feature_extraction.audio import extract_acoustic_features as base_extract_acoustic_features
from feature_extraction.audio import extract_egemaps as base_extract_egemaps

from config.constants import DATA_DIRECTORY, GIT_DIRECTORY

# %%
# adapt some audio functions to accept audio_segment parameter
def extract_acoustic_features(audio_path=None, text=None, duration=None, audio_segment=None):
    if audio_segment is not None:
        # temporarily save to temp wav file
        tmp_path = "/tmp/tmp_combined_audio.wav"
        audio_segment.export(tmp_path, format="wav")
        return base_extract_acoustic_features(tmp_path, text, duration)
    else:
        return base_extract_acoustic_features(audio_path, text, duration)

def extract_egemaps(audio_path=None, audio_segment=None):
    if audio_segment is not None:
        # temporarily save to temp wav file
        tmp_path = "/tmp/tmp_combined_audio.wav"
        audio_segment.export(tmp_path, format="wav")
        return base_extract_egemaps(tmp_path)
    else:
        return base_extract_egemaps(audio_path)

# %%
# set up functions to load transcriptions and audio files

def load_audio_durations(subject_folder):
    path = os.path.join(subject_folder, "audio_durations.csv")
    return pd.read_csv(path) if os.path.exists(path) else pd.DataFrame()

def load_transcriptions(subject_folder):
    path = os.path.join(subject_folder, "ASR", "transcriptions.csv")
    return pd.read_csv(path) if os.path.exists(path) else pd.DataFrame()

def load_audio_file(subject_folder, task):
    path = os.path.join(subject_folder, f"{task}.wav")
    return path if os.path.exists(path) else None

# %%
# function to calculate features across combined audio files and transcriptions

def calculate_combined_features(Subject_ID):
    subject_folder = os.path.join(DATA_DIRECTORY, Subject_ID)
    tasks = ["cookieTheft", "picnicScene", "journaling"]

    transcriptions = load_transcriptions(subject_folder)
    durations = load_audio_durations(subject_folder)

    combined_text = ""
    combined_audio = AudioSegment.silent(duration=0)
    total_duration = 0
    tasks_included = []

    for task in tasks:
        audio_path = load_audio_file(subject_folder, task)
        if audio_path is None: continue

        task_text = transcriptions[transcriptions["task"] == task]["text_google"].values
        task_duration = durations[durations["task"] == task]["duration"].values

        if len(task_text) == 0 or len(task_duration) == 0: continue

        combined_text += " " + task_text[0].strip()
        combined_audio += AudioSegment.from_wav(audio_path)
        total_duration += float(task_duration[0])
        tasks_included.append(task)

    if not combined_text.strip():
        return None # if no task exists

    # load resources for psycholinguistic features
    concreteness_lexicon = load_concreteness_lexicon()
    aoa_lexicon = load_aoa_lexicon()
    frequency_lexicon = load_frequency_norms()
    familiarity_lexicon = load_familiarity_norms()
    imageability_lexicon = load_imageability_norms()

    features = {
        "Subject_ID": Subject_ID,
        "n_words": n_words(combined_text),
        "ttr": ttr(combined_text),
        "average_word_length": avg_word_length(combined_text),
        "filler_word_ratio": filler_word_ratio(combined_text),
        "brunets_index": brunets_index(combined_text),
        "honores_statistic": honores_statistic(combined_text),
        "guirauds_statistic": guirauds_statistic(combined_text),
        "light_verb_ratio": light_verb_ratio(combined_text),
        "empty_word_ratio": empty_word_ratio(combined_text),
        "nid_ratio": nid_ratio(combined_text),
        "adjacent_repetitions": adjacent_repetitions(combined_text),
        "tasks_included": len(tasks_included),
        "task_list": ",".join(tasks_included),
        "total_duration_combined": total_duration
    }

    features.update(mattr(combined_text, window_sizes=[10, 20, 30, 40, 50]))
    features.update(pos_ratios_spacy(combined_text))
    features.update(calculate_fluency_features(combined_text))

    for name, lex in [
        ("aoa", aoa_lexicon),
        ("fam", familiarity_lexicon),
        ("img", imageability_lexicon),
        ("freq", frequency_lexicon),
        ("concr", concreteness_lexicon)
    ]:
        for pos_group, label in [("NOUN", "nouns"), ("VERB", "verbs"), ("NOUN,VERB,ADJ", "content")]:
            pos_list = pos_group.split(",")
            key = f"{name}_{label}"
            features[key] = compute_avg_by_pos(combined_text, lex, pos_list)

    features.update(extract_acoustic_features(audio_segment=combined_audio, text=combined_text, duration=total_duration))
    features.update(extract_egemaps(audio_segment=combined_audio))

    return pd.DataFrame([features])

# %%
# test for one subject

df_test = calculate_combined_features("1370")
print(df_test)
# Out:
#   Subject_ID  n_words       ttr  average_word_length  filler_word_ratio  \
# 0       1370     8136  0.159169             4.163717           0.014135
#
#    brunets_index  honores_statistic  guirauds_statistic  light_verb_ratio  \
# 0      15.800294        1774.771667            14.35702          0.181707
#
#    empty_word_ratio  ...  eGeMAPS_slopeUV0-500_sma3nz_amean  \
# 0          0.000615  ...                           0.026775
#
#    eGeMAPS_slopeUV500-1500_sma3nz_amean  eGeMAPS_spectralFluxUV_sma3nz_amean  \
# 0                             -0.006255                              0.08044
#
#   eGeMAPS_loudnessPeaksPerSec  eGeMAPS_VoicedSegmentsPerSec  \
# 0                    1.323721                      0.182383
#
#    eGeMAPS_MeanVoicedSegmentLengthSec  eGeMAPS_StddevVoicedSegmentLengthSec  \
# 0                             0.28572                              0.285371
#
#    eGeMAPS_MeanUnvoicedSegmentLength  eGeMAPS_StddevUnvoicedSegmentLength  \
# 0                            0.29706                             0.524988
#
#    eGeMAPS_equivalentSoundLevel_dBp
# 0                        -26.679029
#
# [1 rows x 160 columns]

# %%
# run for all subjects and save to csv

output_path = os.path.join(GIT_DIRECTORY, "results", "features", "tasks_combined.csv")

# set up csv-file
# df_sample = calculate_combined_features("1370")
# df_sample.to_csv(output_path, index=False)

# counter
n_saved = 1

all_subjects = sorted([
    folder for folder in os.listdir(DATA_DIRECTORY)
    if os.path.isdir(os.path.join(DATA_DIRECTORY, folder)) and folder.isdigit()
], key=lambda x: int(x))

# load already processed subjects from the csv-file (bc the server deconnected after 100 subjects)
if os.path.exists(output_path):
    processed_df = pd.read_csv(output_path)
    processed_ids = set(processed_df["Subject_ID"].astype(str))
else:
    processed_ids = set()

# process subjects
for Subject_ID in all_subjects:
    if Subject_ID in processed_ids:
        print(f"already processed subject {Subject_ID}, skipping")
        continue
    print(f"processing subject {Subject_ID}")
    try:
        df = calculate_combined_features(Subject_ID)
        if df is not None:
            df.to_csv(output_path, mode='a', header=not os.path.exists(output_path), index=False)
            print(f"added subject {Subject_ID}")
            n_saved += 1
        else:
            print(f"skipped subject {Subject_ID}")
    except Exception as e:
        print(f"error processing subject {Subject_ID}: {e}")


print(f"\n finished saving combined features for {n_saved} subjects to: {output_path}")
# Out:
# already processed subject 41, skipping
# already processed subject 43, skipping
# already processed subject 44, skipping
# already processed subject 46, skipping
# already processed subject 49, skipping
# already processed subject 50, skipping
# already processed subject 54, skipping
# already processed subject 56, skipping
# already processed subject 59, skipping
# already processed subject 61, skipping
# already processed subject 83, skipping
# already processed subject 84, skipping
# already processed subject 85, skipping
# already processed subject 86, skipping
# already processed subject 88, skipping
# already processed subject 89, skipping
# already processed subject 90, skipping
# already processed subject 91, skipping
# already processed subject 92, skipping
# already processed subject 93, skipping
# already processed subject 97, skipping
# already processed subject 98, skipping
# already processed subject 99, skipping
# already processed subject 101, skipping
# already processed subject 102, skipping
# already processed subject 103, skipping
# already processed subject 104, skipping
# already processed subject 105, skipping
# already processed subject 107, skipping
# already processed subject 109, skipping
# already processed subject 110, skipping
# already processed subject 111, skipping
# already processed subject 112, skipping
# already processed subject 115, skipping
# already processed subject 119, skipping
# already processed subject 120, skipping
# already processed subject 122, skipping
# already processed subject 123, skipping
# already processed subject 124, skipping
# already processed subject 127, skipping
# already processed subject 128, skipping
# already processed subject 129, skipping
# already processed subject 130, skipping
# already processed subject 132, skipping
# already processed subject 133, skipping
# already processed subject 134, skipping
# already processed subject 135, skipping
# already processed subject 136, skipping
# already processed subject 137, skipping
# processing subject 138
# error processing subject 138: 'float' object has no attribute 'strip'
# already processed subject 139, skipping
# already processed subject 140, skipping
# already processed subject 141, skipping
# already processed subject 142, skipping
# already processed subject 143, skipping
# already processed subject 145, skipping
# already processed subject 146, skipping
# already processed subject 147, skipping
# already processed subject 149, skipping
# already processed subject 150, skipping
# already processed subject 151, skipping
# already processed subject 152, skipping
# already processed subject 153, skipping
# already processed subject 154, skipping
# already processed subject 157, skipping
# already processed subject 158, skipping
# already processed subject 160, skipping
# already processed subject 162, skipping
# already processed subject 163, skipping
# already processed subject 165, skipping
# already processed subject 169, skipping
# already processed subject 170, skipping
# already processed subject 172, skipping
# already processed subject 173, skipping
# already processed subject 174, skipping
# already processed subject 175, skipping
# already processed subject 176, skipping
# already processed subject 177, skipping
# already processed subject 179, skipping
# already processed subject 183, skipping
# already processed subject 184, skipping
# already processed subject 185, skipping
# already processed subject 186, skipping
# already processed subject 188, skipping
# already processed subject 189, skipping
# already processed subject 190, skipping
# already processed subject 193, skipping
# already processed subject 195, skipping
# already processed subject 196, skipping
# already processed subject 197, skipping
# already processed subject 198, skipping
# already processed subject 199, skipping
# already processed subject 200, skipping
# already processed subject 201, skipping
# already processed subject 202, skipping
# already processed subject 203, skipping
# already processed subject 204, skipping
# already processed subject 205, skipping
# already processed subject 206, skipping
# already processed subject 207, skipping
# already processed subject 208, skipping
# already processed subject 209, skipping
# already processed subject 210, skipping
# already processed subject 211, skipping
# already processed subject 212, skipping
# already processed subject 213, skipping
# already processed subject 214, skipping
# already processed subject 215, skipping
# already processed subject 216, skipping
# already processed subject 217, skipping
# already processed subject 218, skipping
# already processed subject 219, skipping
# already processed subject 220, skipping
# already processed subject 222, skipping
# already processed subject 224, skipping
# already processed subject 225, skipping
# already processed subject 226, skipping
# already processed subject 228, skipping
# already processed subject 229, skipping
# already processed subject 230, skipping
# already processed subject 232, skipping
# already processed subject 233, skipping
# already processed subject 234, skipping
# already processed subject 237, skipping
# already processed subject 239, skipping
# already processed subject 241, skipping
# already processed subject 242, skipping
# already processed subject 243, skipping
# already processed subject 244, skipping
# already processed subject 247, skipping
# already processed subject 248, skipping
# already processed subject 249, skipping
# already processed subject 250, skipping
# already processed subject 251, skipping
# already processed subject 252, skipping
# already processed subject 253, skipping
# already processed subject 254, skipping
# already processed subject 257, skipping
# already processed subject 258, skipping
# already processed subject 260, skipping
# already processed subject 261, skipping
# already processed subject 262, skipping
# already processed subject 263, skipping
# already processed subject 264, skipping
# already processed subject 266, skipping
# already processed subject 267, skipping
# already processed subject 268, skipping
# already processed subject 269, skipping
# already processed subject 270, skipping
# already processed subject 271, skipping
# already processed subject 272, skipping
# already processed subject 274, skipping
# already processed subject 275, skipping
# already processed subject 276, skipping
# already processed subject 277, skipping
# already processed subject 278, skipping
# already processed subject 279, skipping
# already processed subject 282, skipping
# already processed subject 283, skipping
# already processed subject 284, skipping
# already processed subject 288, skipping
# already processed subject 289, skipping
# already processed subject 290, skipping
# already processed subject 291, skipping
# already processed subject 292, skipping
# already processed subject 293, skipping
# already processed subject 294, skipping
# already processed subject 295, skipping
# already processed subject 297, skipping
# already processed subject 298, skipping
# already processed subject 300, skipping
# already processed subject 301, skipping
# already processed subject 303, skipping
# already processed subject 304, skipping
# already processed subject 305, skipping
# already processed subject 306, skipping
# already processed subject 311, skipping
# already processed subject 312, skipping
# already processed subject 314, skipping
# already processed subject 315, skipping
# already processed subject 318, skipping
# already processed subject 319, skipping
# already processed subject 321, skipping
# already processed subject 322, skipping
# already processed subject 324, skipping
# already processed subject 325, skipping
# already processed subject 326, skipping
# already processed subject 327, skipping
# already processed subject 328, skipping
# already processed subject 329, skipping
# already processed subject 330, skipping
# already processed subject 331, skipping
# already processed subject 335, skipping
# already processed subject 336, skipping
# already processed subject 337, skipping
# already processed subject 338, skipping
# already processed subject 339, skipping
# already processed subject 341, skipping
# already processed subject 342, skipping
# already processed subject 343, skipping
# already processed subject 344, skipping
# already processed subject 345, skipping
# already processed subject 346, skipping
# already processed subject 347, skipping
# already processed subject 348, skipping
# already processed subject 349, skipping
# already processed subject 354, skipping
# already processed subject 355, skipping
# already processed subject 356, skipping
# already processed subject 357, skipping
# already processed subject 358, skipping
# already processed subject 359, skipping
# already processed subject 360, skipping
# already processed subject 361, skipping
# already processed subject 362, skipping
# already processed subject 363, skipping
# already processed subject 364, skipping
# already processed subject 365, skipping
# already processed subject 366, skipping
# already processed subject 367, skipping
# already processed subject 368, skipping
# already processed subject 369, skipping
# already processed subject 371, skipping
# already processed subject 372, skipping
# already processed subject 373, skipping
# already processed subject 374, skipping
# already processed subject 375, skipping
# already processed subject 376, skipping
# already processed subject 377, skipping
# already processed subject 378, skipping
# already processed subject 379, skipping
# already processed subject 381, skipping
# already processed subject 382, skipping
# already processed subject 384, skipping
# already processed subject 385, skipping
# already processed subject 386, skipping
# already processed subject 387, skipping
# already processed subject 388, skipping
# already processed subject 389, skipping
# processing subject 390
# error processing subject 390: 'float' object has no attribute 'strip'
# already processed subject 392, skipping
# already processed subject 393, skipping
# already processed subject 394, skipping
# already processed subject 395, skipping
# already processed subject 396, skipping
# already processed subject 397, skipping
# already processed subject 399, skipping
# already processed subject 400, skipping
# already processed subject 401, skipping
# already processed subject 402, skipping
# already processed subject 403, skipping
# already processed subject 404, skipping
# already processed subject 406, skipping
# already processed subject 407, skipping
# already processed subject 409, skipping
# already processed subject 410, skipping
# already processed subject 411, skipping
# already processed subject 415, skipping
# already processed subject 416, skipping
# already processed subject 417, skipping
# already processed subject 419, skipping
# already processed subject 420, skipping
# already processed subject 421, skipping
# already processed subject 423, skipping
# already processed subject 424, skipping
# already processed subject 425, skipping
# already processed subject 427, skipping
# already processed subject 428, skipping
# already processed subject 429, skipping
# already processed subject 430, skipping
# already processed subject 431, skipping
# already processed subject 432, skipping
# already processed subject 433, skipping
# already processed subject 434, skipping
# already processed subject 436, skipping
# already processed subject 437, skipping
# already processed subject 438, skipping
# already processed subject 439, skipping
# already processed subject 441, skipping
# already processed subject 443, skipping
# already processed subject 444, skipping
# already processed subject 445, skipping
# already processed subject 446, skipping
# already processed subject 447, skipping
# already processed subject 448, skipping
# already processed subject 449, skipping
# already processed subject 450, skipping
# already processed subject 451, skipping
# already processed subject 454, skipping
# already processed subject 455, skipping
# already processed subject 459, skipping
# already processed subject 461, skipping
# already processed subject 462, skipping
# already processed subject 463, skipping
# already processed subject 464, skipping
# already processed subject 465, skipping
# already processed subject 466, skipping
# already processed subject 467, skipping
# already processed subject 468, skipping
# processing subject 469
# error processing subject 469: 'float' object has no attribute 'strip'
# already processed subject 470, skipping
# already processed subject 471, skipping
# already processed subject 472, skipping
# already processed subject 473, skipping
# processing subject 474
# error processing subject 474: 'float' object has no attribute 'strip'
# already processed subject 477, skipping
# already processed subject 478, skipping
# already processed subject 479, skipping
# already processed subject 480, skipping
# already processed subject 481, skipping
# already processed subject 483, skipping
# already processed subject 484, skipping
# already processed subject 485, skipping
# already processed subject 487, skipping
# already processed subject 488, skipping
# already processed subject 489, skipping
# already processed subject 490, skipping
# already processed subject 491, skipping
# already processed subject 492, skipping
# already processed subject 493, skipping
# already processed subject 494, skipping
# already processed subject 495, skipping
# already processed subject 496, skipping
# already processed subject 497, skipping
# already processed subject 498, skipping
# already processed subject 499, skipping
# already processed subject 500, skipping
# already processed subject 501, skipping
# already processed subject 502, skipping
# already processed subject 503, skipping
# already processed subject 504, skipping
# already processed subject 505, skipping
# already processed subject 506, skipping
# already processed subject 507, skipping
# already processed subject 508, skipping
# already processed subject 509, skipping
# already processed subject 510, skipping
# already processed subject 511, skipping
# already processed subject 514, skipping
# processing subject 516
# error processing subject 516: 'float' object has no attribute 'strip'
# already processed subject 519, skipping
# already processed subject 520, skipping
# already processed subject 522, skipping
# already processed subject 523, skipping
# already processed subject 524, skipping
# already processed subject 526, skipping
# already processed subject 528, skipping
# already processed subject 530, skipping
# already processed subject 532, skipping
# already processed subject 533, skipping
# already processed subject 534, skipping
# already processed subject 535, skipping
# already processed subject 536, skipping
# already processed subject 537, skipping
# already processed subject 538, skipping
# already processed subject 539, skipping
# already processed subject 540, skipping
# already processed subject 541, skipping
# already processed subject 543, skipping
# already processed subject 545, skipping
# already processed subject 547, skipping
# already processed subject 548, skipping
# already processed subject 549, skipping
# already processed subject 550, skipping
# already processed subject 552, skipping
# already processed subject 553, skipping
# already processed subject 554, skipping
# already processed subject 557, skipping
# already processed subject 558, skipping
# already processed subject 559, skipping
# already processed subject 560, skipping
# already processed subject 562, skipping
# already processed subject 566, skipping
# already processed subject 567, skipping
# already processed subject 568, skipping
# already processed subject 569, skipping
# already processed subject 570, skipping
# already processed subject 574, skipping
# already processed subject 575, skipping
# already processed subject 576, skipping
# already processed subject 577, skipping
# already processed subject 578, skipping
# already processed subject 579, skipping
# already processed subject 580, skipping
# already processed subject 581, skipping
# already processed subject 582, skipping
# already processed subject 583, skipping
# already processed subject 584, skipping
# already processed subject 585, skipping
# already processed subject 586, skipping
# already processed subject 587, skipping
# already processed subject 588, skipping
# already processed subject 589, skipping
# already processed subject 590, skipping
# already processed subject 591, skipping
# already processed subject 592, skipping
# already processed subject 593, skipping
# already processed subject 594, skipping
# already processed subject 596, skipping
# already processed subject 597, skipping
# already processed subject 598, skipping
# already processed subject 600, skipping
# already processed subject 602, skipping
# already processed subject 603, skipping
# already processed subject 604, skipping
# already processed subject 605, skipping
# already processed subject 606, skipping
# already processed subject 607, skipping
# already processed subject 609, skipping
# already processed subject 610, skipping
# already processed subject 611, skipping
# already processed subject 612, skipping
# already processed subject 613, skipping
# already processed subject 614, skipping
# already processed subject 615, skipping
# already processed subject 617, skipping
# already processed subject 618, skipping
# already processed subject 619, skipping
# already processed subject 620, skipping
# already processed subject 621, skipping
# already processed subject 622, skipping
# already processed subject 623, skipping
# already processed subject 624, skipping
# already processed subject 625, skipping
# already processed subject 626, skipping
# already processed subject 627, skipping
# already processed subject 628, skipping
# already processed subject 629, skipping
# already processed subject 631, skipping
# already processed subject 632, skipping
# already processed subject 633, skipping
# already processed subject 636, skipping
# already processed subject 637, skipping
# already processed subject 638, skipping
# already processed subject 640, skipping
# already processed subject 641, skipping
# already processed subject 643, skipping
# already processed subject 644, skipping
# already processed subject 645, skipping
# already processed subject 646, skipping
# already processed subject 647, skipping
# already processed subject 648, skipping
# already processed subject 649, skipping
# already processed subject 650, skipping
# already processed subject 651, skipping
# already processed subject 652, skipping
# already processed subject 653, skipping
# already processed subject 655, skipping
# already processed subject 656, skipping
# already processed subject 657, skipping
# already processed subject 659, skipping
# already processed subject 660, skipping
# already processed subject 661, skipping
# already processed subject 662, skipping
# already processed subject 663, skipping
# already processed subject 664, skipping
# already processed subject 665, skipping
# already processed subject 666, skipping
# already processed subject 667, skipping
# already processed subject 668, skipping
# already processed subject 669, skipping
# already processed subject 670, skipping
# already processed subject 671, skipping
# already processed subject 672, skipping
# already processed subject 673, skipping
# already processed subject 674, skipping
# already processed subject 675, skipping
# already processed subject 676, skipping
# already processed subject 677, skipping
# already processed subject 678, skipping
# already processed subject 679, skipping
# already processed subject 680, skipping
# already processed subject 681, skipping
# already processed subject 682, skipping
# already processed subject 683, skipping
# already processed subject 684, skipping
# already processed subject 688, skipping
# already processed subject 689, skipping
# already processed subject 690, skipping
# already processed subject 691, skipping
# already processed subject 692, skipping
# already processed subject 693, skipping
# already processed subject 694, skipping
# already processed subject 696, skipping
# already processed subject 697, skipping
# already processed subject 698, skipping
# already processed subject 701, skipping
# already processed subject 702, skipping
# already processed subject 703, skipping
# already processed subject 704, skipping
# already processed subject 705, skipping
# already processed subject 706, skipping
# already processed subject 707, skipping
# already processed subject 708, skipping
# already processed subject 709, skipping
# already processed subject 710, skipping
# already processed subject 712, skipping
# already processed subject 713, skipping
# already processed subject 714, skipping
# already processed subject 717, skipping
# already processed subject 719, skipping
# already processed subject 720, skipping
# already processed subject 721, skipping
# already processed subject 722, skipping
# already processed subject 723, skipping
# already processed subject 724, skipping
# already processed subject 725, skipping
# already processed subject 727, skipping
# already processed subject 728, skipping
# already processed subject 729, skipping
# already processed subject 732, skipping
# already processed subject 733, skipping
# already processed subject 734, skipping
# already processed subject 735, skipping
# already processed subject 737, skipping
# already processed subject 738, skipping
# already processed subject 739, skipping
# already processed subject 741, skipping
# already processed subject 742, skipping
# already processed subject 743, skipping
# already processed subject 744, skipping
# already processed subject 745, skipping
# already processed subject 747, skipping
# already processed subject 748, skipping
# already processed subject 749, skipping
# already processed subject 750, skipping
# already processed subject 753, skipping
# already processed subject 754, skipping
# already processed subject 755, skipping
# already processed subject 756, skipping
# already processed subject 757, skipping
# already processed subject 758, skipping
# already processed subject 760, skipping
# already processed subject 761, skipping
# already processed subject 762, skipping
# already processed subject 763, skipping
# already processed subject 764, skipping
# already processed subject 765, skipping
# already processed subject 766, skipping
# already processed subject 767, skipping
# already processed subject 768, skipping
# already processed subject 769, skipping
# already processed subject 770, skipping
# already processed subject 771, skipping
# already processed subject 772, skipping
# already processed subject 773, skipping
# already processed subject 774, skipping
# already processed subject 775, skipping
# already processed subject 776, skipping
# already processed subject 777, skipping
# already processed subject 778, skipping
# already processed subject 779, skipping
# already processed subject 780, skipping
# already processed subject 781, skipping
# already processed subject 782, skipping
# already processed subject 783, skipping
# already processed subject 784, skipping
# already processed subject 786, skipping
# already processed subject 787, skipping
# already processed subject 788, skipping
# already processed subject 789, skipping
# already processed subject 790, skipping
# already processed subject 791, skipping
# already processed subject 793, skipping
# already processed subject 794, skipping
# already processed subject 796, skipping
# already processed subject 797, skipping
# already processed subject 799, skipping
# already processed subject 800, skipping
# already processed subject 801, skipping
# already processed subject 802, skipping
# already processed subject 803, skipping
# already processed subject 805, skipping
# already processed subject 807, skipping
# already processed subject 808, skipping
# already processed subject 809, skipping
# already processed subject 811, skipping
# already processed subject 812, skipping
# already processed subject 814, skipping
# already processed subject 816, skipping
# already processed subject 819, skipping
# already processed subject 820, skipping
# already processed subject 821, skipping
# already processed subject 822, skipping
# already processed subject 823, skipping
# already processed subject 824, skipping
# already processed subject 826, skipping
# already processed subject 827, skipping
# already processed subject 828, skipping
# already processed subject 829, skipping
# already processed subject 830, skipping
# already processed subject 831, skipping
# already processed subject 833, skipping
# already processed subject 834, skipping
# already processed subject 835, skipping
# already processed subject 836, skipping
# already processed subject 838, skipping
# already processed subject 839, skipping
# already processed subject 840, skipping
# already processed subject 841, skipping
# already processed subject 842, skipping
# already processed subject 843, skipping
# already processed subject 844, skipping
# already processed subject 845, skipping
# already processed subject 847, skipping
# already processed subject 848, skipping
# already processed subject 849, skipping
# already processed subject 851, skipping
# already processed subject 852, skipping
# already processed subject 853, skipping
# already processed subject 854, skipping
# already processed subject 855, skipping
# already processed subject 856, skipping
# already processed subject 857, skipping
# already processed subject 858, skipping
# already processed subject 859, skipping
# already processed subject 862, skipping
# already processed subject 863, skipping
# already processed subject 864, skipping
# already processed subject 866, skipping
# already processed subject 867, skipping
# already processed subject 868, skipping
# already processed subject 871, skipping
# already processed subject 872, skipping
# already processed subject 873, skipping
# already processed subject 874, skipping
# already processed subject 875, skipping
# already processed subject 876, skipping
# already processed subject 877, skipping
# already processed subject 883, skipping
# already processed subject 884, skipping
# already processed subject 885, skipping
# already processed subject 887, skipping
# already processed subject 888, skipping
# already processed subject 889, skipping
# already processed subject 890, skipping
# already processed subject 891, skipping
# already processed subject 892, skipping
# already processed subject 893, skipping
# already processed subject 894, skipping
# already processed subject 895, skipping
# already processed subject 897, skipping
# already processed subject 898, skipping
# already processed subject 899, skipping
# already processed subject 901, skipping
# already processed subject 902, skipping
# already processed subject 903, skipping
# already processed subject 904, skipping
# already processed subject 906, skipping
# already processed subject 908, skipping
# already processed subject 909, skipping
# already processed subject 910, skipping
# already processed subject 911, skipping
# already processed subject 912, skipping
# already processed subject 913, skipping
# already processed subject 914, skipping
# already processed subject 916, skipping
# already processed subject 917, skipping
# already processed subject 918, skipping
# already processed subject 919, skipping
# already processed subject 920, skipping
# already processed subject 921, skipping
# already processed subject 922, skipping
# already processed subject 923, skipping
# already processed subject 924, skipping
# already processed subject 927, skipping
# already processed subject 928, skipping
# already processed subject 929, skipping
# already processed subject 931, skipping
# already processed subject 932, skipping
# already processed subject 933, skipping
# already processed subject 934, skipping
# already processed subject 935, skipping
# already processed subject 936, skipping
# already processed subject 938, skipping
# already processed subject 941, skipping
# already processed subject 942, skipping
# already processed subject 943, skipping
# already processed subject 944, skipping
# already processed subject 945, skipping
# already processed subject 947, skipping
# already processed subject 948, skipping
# already processed subject 950, skipping
# already processed subject 951, skipping
# already processed subject 952, skipping
# already processed subject 953, skipping
# already processed subject 954, skipping
# already processed subject 956, skipping
# already processed subject 957, skipping
# already processed subject 958, skipping
# already processed subject 960, skipping
# already processed subject 962, skipping
# already processed subject 963, skipping
# already processed subject 964, skipping
# already processed subject 965, skipping
# already processed subject 966, skipping
# already processed subject 967, skipping
# already processed subject 968, skipping
# already processed subject 969, skipping
# already processed subject 970, skipping
# already processed subject 971, skipping
# already processed subject 972, skipping
# already processed subject 973, skipping
# already processed subject 975, skipping
# already processed subject 979, skipping
# already processed subject 981, skipping
# already processed subject 982, skipping
# already processed subject 983, skipping
# already processed subject 984, skipping
# already processed subject 985, skipping
# already processed subject 986, skipping
# already processed subject 988, skipping
# already processed subject 989, skipping
# already processed subject 991, skipping
# already processed subject 993, skipping
# already processed subject 994, skipping
# already processed subject 997, skipping
# already processed subject 998, skipping
# already processed subject 999, skipping
# already processed subject 1000, skipping
# already processed subject 1001, skipping
# already processed subject 1002, skipping
# already processed subject 1003, skipping
# already processed subject 1004, skipping
# already processed subject 1005, skipping
# already processed subject 1006, skipping
# already processed subject 1007, skipping
# already processed subject 1008, skipping
# already processed subject 1009, skipping
# already processed subject 1010, skipping
# already processed subject 1011, skipping
# already processed subject 1012, skipping
# already processed subject 1013, skipping
# already processed subject 1014, skipping
# already processed subject 1015, skipping
# already processed subject 1016, skipping
# already processed subject 1017, skipping
# already processed subject 1018, skipping
# already processed subject 1019, skipping
# already processed subject 1020, skipping
# already processed subject 1021, skipping
# already processed subject 1022, skipping
# already processed subject 1023, skipping
# already processed subject 1024, skipping
# already processed subject 1025, skipping
# already processed subject 1026, skipping
# already processed subject 1027, skipping
# already processed subject 1028, skipping
# already processed subject 1029, skipping
# already processed subject 1030, skipping
# already processed subject 1032, skipping
# already processed subject 1036, skipping
# already processed subject 1037, skipping
# already processed subject 1038, skipping
# already processed subject 1039, skipping
# already processed subject 1040, skipping
# already processed subject 1041, skipping
# already processed subject 1044, skipping
# already processed subject 1045, skipping
# already processed subject 1046, skipping
# already processed subject 1047, skipping
# already processed subject 1048, skipping
# already processed subject 1049, skipping
# already processed subject 1050, skipping
# already processed subject 1051, skipping
# already processed subject 1052, skipping
# already processed subject 1053, skipping
# already processed subject 1054, skipping
# already processed subject 1055, skipping
# already processed subject 1056, skipping
# already processed subject 1057, skipping
# already processed subject 1058, skipping
# already processed subject 1059, skipping
# already processed subject 1060, skipping
# already processed subject 1061, skipping
# already processed subject 1062, skipping
# already processed subject 1063, skipping
# already processed subject 1065, skipping
# already processed subject 1067, skipping
# already processed subject 1069, skipping
# already processed subject 1070, skipping
# already processed subject 1071, skipping
# already processed subject 1072, skipping
# already processed subject 1073, skipping
# already processed subject 1074, skipping
# already processed subject 1075, skipping
# already processed subject 1079, skipping
# already processed subject 1080, skipping
# already processed subject 1082, skipping
# already processed subject 1083, skipping
# already processed subject 1086, skipping
# already processed subject 1087, skipping
# already processed subject 1088, skipping
# already processed subject 1089, skipping
# already processed subject 1090, skipping
# already processed subject 1093, skipping
# already processed subject 1094, skipping
# already processed subject 1095, skipping
# already processed subject 1096, skipping
# already processed subject 1097, skipping
# already processed subject 1098, skipping
# already processed subject 1099, skipping
# already processed subject 1100, skipping
# already processed subject 1101, skipping
# already processed subject 1102, skipping
# already processed subject 1104, skipping
# already processed subject 1105, skipping
# already processed subject 1106, skipping
# already processed subject 1107, skipping
# already processed subject 1112, skipping
# already processed subject 1113, skipping
# already processed subject 1114, skipping
# already processed subject 1115, skipping
# already processed subject 1116, skipping
# already processed subject 1117, skipping
# already processed subject 1118, skipping
# already processed subject 1119, skipping
# already processed subject 1120, skipping
# already processed subject 1123, skipping
# already processed subject 1124, skipping
# already processed subject 1125, skipping
# already processed subject 1128, skipping
# already processed subject 1130, skipping
# already processed subject 1131, skipping
# already processed subject 1132, skipping
# already processed subject 1133, skipping
# already processed subject 1134, skipping
# already processed subject 1135, skipping
# already processed subject 1136, skipping
# already processed subject 1138, skipping
# already processed subject 1139, skipping
# already processed subject 1140, skipping
# already processed subject 1141, skipping
# already processed subject 1142, skipping
# already processed subject 1144, skipping
# already processed subject 1146, skipping
# already processed subject 1147, skipping
# already processed subject 1148, skipping
# already processed subject 1149, skipping
# already processed subject 1150, skipping
# already processed subject 1152, skipping
# already processed subject 1155, skipping
# already processed subject 1160, skipping
# already processed subject 1161, skipping
# already processed subject 1162, skipping
# already processed subject 1164, skipping
# already processed subject 1165, skipping
# already processed subject 1166, skipping
# already processed subject 1167, skipping
# already processed subject 1168, skipping
# already processed subject 1169, skipping
# already processed subject 1170, skipping
# already processed subject 1172, skipping
# already processed subject 1174, skipping
# already processed subject 1175, skipping
# already processed subject 1176, skipping
# already processed subject 1177, skipping
# already processed subject 1179, skipping
# already processed subject 1180, skipping
# already processed subject 1183, skipping
# already processed subject 1185, skipping
# already processed subject 1186, skipping
# already processed subject 1188, skipping
# already processed subject 1189, skipping
# already processed subject 1190, skipping
# already processed subject 1191, skipping
# already processed subject 1192, skipping
# already processed subject 1193, skipping
# already processed subject 1194, skipping
# already processed subject 1195, skipping
# already processed subject 1196, skipping
# already processed subject 1198, skipping
# already processed subject 1199, skipping
# already processed subject 1200, skipping
# already processed subject 1201, skipping
# already processed subject 1202, skipping
# already processed subject 1203, skipping
# already processed subject 1204, skipping
# already processed subject 1205, skipping
# already processed subject 1206, skipping
# already processed subject 1207, skipping
# already processed subject 1209, skipping
# already processed subject 1211, skipping
# already processed subject 1212, skipping
# already processed subject 1213, skipping
# already processed subject 1214, skipping
# already processed subject 1215, skipping
# already processed subject 1216, skipping
# already processed subject 1217, skipping
# already processed subject 1218, skipping
# already processed subject 1219, skipping
# already processed subject 1220, skipping
# already processed subject 1222, skipping
# already processed subject 1223, skipping
# already processed subject 1225, skipping
# already processed subject 1227, skipping
# already processed subject 1228, skipping
# already processed subject 1229, skipping
# already processed subject 1230, skipping
# already processed subject 1232, skipping
# already processed subject 1233, skipping
# already processed subject 1234, skipping
# already processed subject 1235, skipping
# already processed subject 1237, skipping
# already processed subject 1238, skipping
# already processed subject 1239, skipping
# already processed subject 1240, skipping
# already processed subject 1241, skipping
# already processed subject 1242, skipping
# already processed subject 1244, skipping
# already processed subject 1245, skipping
# already processed subject 1246, skipping
# already processed subject 1247, skipping
# already processed subject 1248, skipping
# already processed subject 1249, skipping
# already processed subject 1250, skipping
# already processed subject 1251, skipping
# already processed subject 1252, skipping
# already processed subject 1253, skipping
# already processed subject 1254, skipping
# already processed subject 1255, skipping
# already processed subject 1257, skipping
# already processed subject 1258, skipping
# already processed subject 1264, skipping
# already processed subject 1266, skipping
# already processed subject 1267, skipping
# already processed subject 1268, skipping
# already processed subject 1271, skipping
# already processed subject 1274, skipping
# already processed subject 1275, skipping
# already processed subject 1276, skipping
# already processed subject 1277, skipping
# already processed subject 1278, skipping
# already processed subject 1280, skipping
# already processed subject 1281, skipping
# already processed subject 1282, skipping
# already processed subject 1283, skipping
# already processed subject 1284, skipping
# already processed subject 1285, skipping
# already processed subject 1286, skipping
# already processed subject 1288, skipping
# already processed subject 1290, skipping
# already processed subject 1291, skipping
# already processed subject 1292, skipping
# already processed subject 1293, skipping
# already processed subject 1294, skipping
# already processed subject 1295, skipping
# already processed subject 1297, skipping
# already processed subject 1298, skipping
# already processed subject 1299, skipping
# already processed subject 1302, skipping
# already processed subject 1304, skipping
# already processed subject 1305, skipping
# already processed subject 1308, skipping
# already processed subject 1309, skipping
# already processed subject 1310, skipping
# already processed subject 1311, skipping
# already processed subject 1312, skipping
# already processed subject 1313, skipping
# already processed subject 1314, skipping
# already processed subject 1315, skipping
# already processed subject 1316, skipping
# already processed subject 1317, skipping
# already processed subject 1318, skipping
# already processed subject 1319, skipping
# already processed subject 1320, skipping
# already processed subject 1322, skipping
# already processed subject 1324, skipping
# already processed subject 1325, skipping
# already processed subject 1326, skipping
# already processed subject 1327, skipping
# already processed subject 1328, skipping
# already processed subject 1330, skipping
# already processed subject 1331, skipping
# already processed subject 1332, skipping
# already processed subject 1334, skipping
# already processed subject 1336, skipping
# already processed subject 1339, skipping
# already processed subject 1340, skipping
# already processed subject 1341, skipping
# already processed subject 1344, skipping
# already processed subject 1346, skipping
# already processed subject 1347, skipping
# already processed subject 1348, skipping
# already processed subject 1349, skipping
# already processed subject 1350, skipping
# already processed subject 1351, skipping
# already processed subject 1353, skipping
# already processed subject 1354, skipping
# already processed subject 1355, skipping
# already processed subject 1356, skipping
# already processed subject 1357, skipping
# already processed subject 1358, skipping
# already processed subject 1359, skipping
# already processed subject 1360, skipping
# already processed subject 1361, skipping
# already processed subject 1362, skipping
# already processed subject 1363, skipping
# already processed subject 1365, skipping
# already processed subject 1366, skipping
# already processed subject 1368, skipping
# already processed subject 1369, skipping
# already processed subject 1370, skipping
#
#  finished saving combined features for 1 subjects to: /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/tasks_combined.csv
