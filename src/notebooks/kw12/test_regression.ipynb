# %%
import sys
import os

# Add project root to the path
sys.path.append("/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/src")

from regression.multiple_regression import run_multiple_regression

# Just to confirm things work
print("Function imported successfully!")
# Out:
# Function imported successfully!

# %%
# Paths to files
features_path = "/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/cookieTheft.csv"
scores_path = "/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/resources/language_scores_all_subjects.csv"
output_dir = "/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/regression"

# %%
# %%
target = "PhonemicFluencyScore"

model, results_df, vif_df = run_multiple_regression(
    features_path=features_path,
    scores_path=scores_path,
    target=target,
    output_dir=output_dir
)

# Show quick results
results_df.head()
# Out:
# /opt/anaconda3/envs/nlp_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /opt/anaconda3/envs/nlp_env/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /opt/anaconda3/envs/nlp_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#                index  coefficient   p_value      std_err   t_value  r_squared  \
# 0              const -2134.846918  0.131457  1413.664021 -1.510152   0.210747
# 1            n_words     0.003636  0.589251     0.006731  0.540171   0.210747
# 2                ttr     6.391630  0.240043     5.435610  1.175881   0.210747
# ...

# %%
vif_df
# Out:
#                                   feature        VIF
# 0                                   const   0.000000
# 1                                 n_words  64.502038
# 2                                     ttr   6.018614
# 3                                   mattr   3.302302
# 4                       filler_word_ratio   9.756809
# ..                                    ...        ...
# 123    eGeMAPS_MeanVoicedSegmentLengthSec  27.024737
# 124  eGeMAPS_StddevVoicedSegmentLengthSec  28.979975
# 125     eGeMAPS_MeanUnvoicedSegmentLength  26.866947
# 126   eGeMAPS_StddevUnvoicedSegmentLength   9.288412
# 127      eGeMAPS_equivalentSoundLevel_dBp   7.530745
#
# [128 rows x 2 columns]
