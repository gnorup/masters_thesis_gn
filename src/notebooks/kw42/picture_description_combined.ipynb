# %% [markdown]
# combined picture description features BUT: old version without random task order (always cookieTheft first, probably biased)

# %%
import os, sys, contextlib, wave, tempfile, json
import pandas as pd
from pydub import AudioSegment

# project root
sys.path.append("/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/src")

from config.constants import DATA_DIRECTORY, GIT_DIRECTORY

# linguistic features
from feature_extraction.features import (
    n_words, pos_ratios_spacy, filler_word_ratio, ttr, mattr, avg_word_length,
    light_verb_ratio, empty_word_ratio, nid_ratio, adjacent_repetitions,
    brunets_index, honores_statistic, guirauds_statistic
)
from feature_extraction.features.psycholinguistic_features import (
    compute_avg_by_pos, load_aoa_lexicon, load_imageability_norms,
    load_familiarity_norms, load_frequency_norms, load_concreteness_lexicon
)
from feature_extraction.features.fluency_features import calculate_fluency_features

# audio features
from feature_extraction.audio import (
    extract_acoustic_features as base_extract_acoustic_features,
    extract_egemaps as base_extract_egemaps,
)

# article-pause-contentword (expects CSV path of word timestamps)
from feature_extraction.features.article_pause_contentword import article_pause_contentword

# config 

PICTURE_TASKS = ["cookieTheft", "picnicScene"]
TIMESTAMP_ROOT = "/Volumes/g_psyplafor_methlab$/Students/Gila/word_timestamps"
OUT_DIR = os.path.join(GIT_DIRECTORY, "results", "features")

OUTPUTS = {
    "picture_description.csv":        300,  # 5:00
    "picture_description_1min.csv":   60,   # 1:00
    "picture_description_2min.csv":   120,  # 2:00
}

#  helpers 

def _infer_wav_duration_seconds(wav_path: str):
    try:
        with contextlib.closing(wave.open(wav_path, 'r')) as w:
            return w.getnframes() / float(w.getframerate())
    except Exception:
        return None

def load_transcriptions(subject_folder):
    p = os.path.join(subject_folder, "ASR", "transcriptions.csv")
    return pd.read_csv(p) if os.path.exists(p) else pd.DataFrame()

def load_audio_durations(subject_folder):
    p = os.path.join(subject_folder, "audio_durations.csv")
    return pd.read_csv(p) if os.path.exists(p) else pd.DataFrame()

def load_task_word_timestamps(subject_id: str, task: str) -> pd.DataFrame | None:
    p = os.path.join(TIMESTAMP_ROOT, task, "google", "timestamps", f"{subject_id}.csv")
    if not os.path.exists(p):
        return None
    df = pd.read_csv(p)
    need = ["word", "start", "end"]
    if not all(c in df.columns for c in need):
        return None
    df = df[need].copy()
    df["start"] = pd.to_numeric(df["start"], errors="coerce")
    df["end"]   = pd.to_numeric(df["end"], errors="coerce")
    df = df.dropna(subset=["word", "start", "end"])
    return df

def load_audio_file(subject_folder, task):
    p = os.path.join(subject_folder, f"{task}.wav")
    return p if os.path.exists(p) else None

def extract_acoustic_features(audio_path=None, text=None, duration=None, audio_segment=None):
    if audio_segment is not None:
        tmp_path = os.path.join(tempfile.gettempdir(), "tmp_picdesc_audio.wav")
        audio_segment.export(tmp_path, format="wav")
        return base_extract_acoustic_features(tmp_path, text, duration)
    return base_extract_acoustic_features(audio_path, text, duration)

def extract_egemaps(audio_path=None, audio_segment=None):
    if audio_segment is not None:
        tmp_path = os.path.join(tempfile.gettempdir(), "tmp_picdesc_audio.wav")
        audio_segment.export(tmp_path, format="wav")
        return base_extract_egemaps(tmp_path)
    return base_extract_egemaps(audio_path)

# append + checkpoint 

def append_row_atomic(out_path: str, row_df: pd.DataFrame):
    exists = os.path.exists(out_path)
    # append one row; write header only if new file
    row_df.to_csv(out_path, mode="a", header=not exists, index=False)
    # extra safety: force flush to disk
    with open(out_path, "a") as f:
        f.flush()
        os.fsync(f.fileno())

def load_checkpoint(ckpt_path: str) -> set[str]:
    if not os.path.exists(ckpt_path):
        return set()
    try:
        with open(ckpt_path, "r") as f:
            return set(json.load(f))
    except Exception:
        return set()

def save_checkpoint(ckpt_path: str, processed_ids: set[str]):
    tmp = ckpt_path + ".tmp"
    with open(tmp, "w") as f:
        json.dump(sorted(processed_ids), f)
        f.flush()
        os.fsync(f.fileno())
    os.replace(tmp, ckpt_path)  # atomic rename

#  core assembly 

def combine_picture_description_streams(subject_id: str):
    subject_folder = os.path.join(DATA_DIRECTORY, subject_id)
    trans = load_transcriptions(subject_folder)
    durs  = load_audio_durations(subject_folder)

    combined_audio = AudioSegment.silent(duration=0)
    total_offset = 0.0
    tasks_included, words_blocks, text_fallbacks = [], [], []

    for task in PICTURE_TASKS:
        wav = load_audio_file(subject_folder, task)
        if wav is None:
            continue

        seg = AudioSegment.from_wav(wav)
        dur_audio = len(seg) / 1000.0
        d = durs[durs["task"] == task]["duration"].values
        dur = max(float(d[0]), dur_audio) if len(d) else dur_audio

        wdf = load_task_word_timestamps(subject_id, task)
        if wdf is not None and not wdf.empty:
            wdf2 = wdf.copy()
            wdf2["start"] = wdf2["start"].astype(float) + total_offset
            wdf2["end"]   = wdf2["end"].astype(float) + total_offset
            words_blocks.append(wdf2)
        else:
            t = trans[trans["task"] == task]["text_google"].values
            if len(t) and isinstance(t[0], str) and t[0].strip():
                text_fallbacks.append(t[0].strip())

        combined_audio += seg
        total_offset += dur
        tasks_included.append(task)

    combined_words = pd.concat(words_blocks, ignore_index=True) if words_blocks else None
    if combined_words is not None and not combined_words.empty:
        combined_text = " ".join(combined_words["word"].tolist())
    else:
        combined_text = " ".join(text_fallbacks).strip()

    if not combined_text:
        return None, None, 0.0, [], None

    return combined_text, combined_audio, total_offset, tasks_included, combined_words

def truncate_by_seconds(combined_text, combined_audio, combined_words, cap_seconds):
    if cap_seconds is None:
        return combined_text, combined_audio, combined_words
    ms = int(cap_seconds * 1000)
    audio_cut = combined_audio[:ms]
    if combined_words is not None and not combined_words.empty:
        kept = combined_words[combined_words["end"] <= cap_seconds].copy()
        text_cut = " ".join(kept["word"].tolist())
        return text_cut, audio_cut, kept
    return combined_text, audio_cut, None

def compute_features_for_slice(subject_id: str, text: str, audio_cut: AudioSegment, words_cut: pd.DataFrame | None):
    # lexica
    concreteness_lexicon = load_concreteness_lexicon()
    aoa_lexicon = load_aoa_lexicon()
    frequency_lexicon = load_frequency_norms()
    familiarity_lexicon = load_familiarity_norms()
    imageability_lexicon = load_imageability_norms()

    used_dur = len(audio_cut) / 1000.0

    feats = {
        "Subject_ID": subject_id,
        "duration_used_sec": used_dur,
        "n_words": n_words(text),
        "ttr": ttr(text),
        "average_word_length": avg_word_length(text),
        "filler_word_ratio": filler_word_ratio(text),
        "brunets_index": brunets_index(text),
        "honores_statistic": honores_statistic(text),
        "guirauds_statistic": guirauds_statistic(text),
        "light_verb_ratio": light_verb_ratio(text),
        "empty_word_ratio": empty_word_ratio(text),
        "nid_ratio": nid_ratio(text),
        "adjacent_repetitions": adjacent_repetitions(text),
    }
    feats.update(mattr(text, window_sizes=[10,20,30,40,50]))
    feats.update(pos_ratios_spacy(text))
    feats.update(calculate_fluency_features(text))

    for name, lex in [
        ("aoa",  aoa_lexicon),
        ("fam",  familiarity_lexicon),
        ("img",  imageability_lexicon),
        ("freq", frequency_lexicon),
        ("concr",concreteness_lexicon),
    ]:
        feats[f"{name}_nouns"]   = compute_avg_by_pos(text, lex, ["NOUN"])
        feats[f"{name}_verbs"]   = compute_avg_by_pos(text, lex, ["VERB"])
        feats[f"{name}_content"] = compute_avg_by_pos(text, lex, ["NOUN","VERB","ADJ"])

    feats.update(extract_acoustic_features(audio_segment=audio_cut, text=text, duration=used_dur))
    feats.update(extract_egemaps(audio_segment=audio_cut))

    # article_pause_contentword on CUT timestamps (if available)
    if words_cut is not None and not words_cut.empty:
        with tempfile.NamedTemporaryFile(suffix=".csv", delete=False) as tmpf:
            tmp_path = tmpf.name
        words_cut[["word","start","end"]].to_csv(tmp_path, index=False)
        try:
            apc = article_pause_contentword(tmp_path)
        except Exception:
            apc = None
        finally:
            try:
                os.remove(tmp_path)
            except Exception:
                pass
        feats["article_pause_contentword"] = apc
    else:
        feats["article_pause_contentword"] = None

    return pd.DataFrame([feats])

#  run 

def main():
    os.makedirs(OUT_DIR, exist_ok=True)
    CKPT_DIR = os.path.join(OUT_DIR, "_checkpoints")
    os.makedirs(CKPT_DIR, exist_ok=True)

    subjects = sorted([
        s for s in os.listdir(DATA_DIRECTORY)
        if os.path.isdir(os.path.join(DATA_DIRECTORY, s)) and s.isdigit()
    ], key=lambda x: int(x))

    # load processed sets from checkpoints if present; else from existing CSVs
    processed = {}
    for fname in OUTPUTS.keys():
        ckpt_path = os.path.join(CKPT_DIR, fname + ".json")
        done = load_checkpoint(ckpt_path)
        if not done:
            out_path = os.path.join(OUT_DIR, fname)
            if os.path.exists(out_path):
                try:
                    dfp = pd.read_csv(out_path, usecols=["Subject_ID"])
                    done = set(dfp["Subject_ID"].astype(str))
                except Exception:
                    done = set()
        processed[fname] = done

    for sid in subjects:
        subj_folder = os.path.join(DATA_DIRECTORY, sid)
        if not any(os.path.exists(os.path.join(subj_folder, f"{t}.wav")) for t in PICTURE_TASKS):
            print(f"[skip] {sid}: no picture-description audio")
            continue

        combo = combine_picture_description_streams(sid)
        if combo[3] == []:
            print(f"[skip] {sid}: no picture-description data")
            continue
        combined_text, combined_audio, _total, _tasks_included, combined_words = combo

        # compute once, then reuse for each cap/file
        for fname, cap in OUTPUTS.items():
            out_path = os.path.join(OUT_DIR, fname)
            ckpt_path = os.path.join(CKPT_DIR, fname + ".json")

            if sid in processed[fname]:
                print(f"[{fname}] already processed {sid}, skipping")
                continue

            print(f"[{fname}] processing {sid} (cap={cap}s)")
            text_cut, audio_cut, words_cut = truncate_by_seconds(
                combined_text, combined_audio, combined_words, cap
            )

            try:
                df_slice = compute_features_for_slice(
                    sid, text=text_cut, audio_cut=audio_cut, words_cut=words_cut
                )
                append_row_atomic(out_path, df_slice)                # <- append immediately
                processed[fname].add(sid)                            # <- mark done
                save_checkpoint(ckpt_path, processed[fname])         # <- persist progress
            except Exception as e:
                print(f"[{fname}] ERROR {sid}: {e}")
                # don't checkpoint on error; we'll retry next run
                continue

    print("\nDone. Wrote/updated:")
    for fname in OUTPUTS.keys():
        print(" -", os.path.join(OUT_DIR, fname))

if __name__ == "__main__":
    main()
# Out:
# [picture_description.csv] already processed 41, skipping
# [picture_description_1min.csv] already processed 41, skipping
# [picture_description_2min.csv] already processed 41, skipping
# [picture_description.csv] already processed 43, skipping
# [picture_description_1min.csv] already processed 43, skipping
# [picture_description_2min.csv] already processed 43, skipping
# [picture_description.csv] already processed 44, skipping
# [picture_description_1min.csv] already processed 44, skipping
# [picture_description_2min.csv] already processed 44, skipping
# [picture_description.csv] already processed 46, skipping
# [picture_description_1min.csv] already processed 46, skipping
# [picture_description_2min.csv] already processed 46, skipping
# [picture_description.csv] already processed 49, skipping
# [picture_description_1min.csv] already processed 49, skipping
# [picture_description_2min.csv] already processed 49, skipping
# [picture_description.csv] already processed 50, skipping
# [picture_description_1min.csv] already processed 50, skipping
# [picture_description_2min.csv] already processed 50, skipping
# [picture_description.csv] already processed 54, skipping
# [picture_description_1min.csv] already processed 54, skipping
# [picture_description_2min.csv] already processed 54, skipping
# [picture_description.csv] already processed 56, skipping
# [picture_description_1min.csv] already processed 56, skipping
# [picture_description_2min.csv] already processed 56, skipping
# [picture_description.csv] already processed 59, skipping
# [picture_description_1min.csv] already processed 59, skipping
# [picture_description_2min.csv] already processed 59, skipping
# [picture_description.csv] already processed 61, skipping
# [picture_description_1min.csv] already processed 61, skipping
# [picture_description_2min.csv] already processed 61, skipping
# [picture_description.csv] already processed 83, skipping
# [picture_description_1min.csv] already processed 83, skipping
# [picture_description_2min.csv] already processed 83, skipping
# [picture_description.csv] already processed 84, skipping
# [picture_description_1min.csv] already processed 84, skipping
# [picture_description_2min.csv] already processed 84, skipping
# [picture_description.csv] already processed 85, skipping
# [picture_description_1min.csv] already processed 85, skipping
# [picture_description_2min.csv] already processed 85, skipping
# [picture_description.csv] already processed 86, skipping
# [picture_description_1min.csv] already processed 86, skipping
# [picture_description_2min.csv] already processed 86, skipping
# [picture_description.csv] already processed 88, skipping
# [picture_description_1min.csv] already processed 88, skipping
# [picture_description_2min.csv] already processed 88, skipping
# [picture_description.csv] already processed 89, skipping
# [picture_description_1min.csv] already processed 89, skipping
# [picture_description_2min.csv] already processed 89, skipping
# [picture_description.csv] already processed 90, skipping
# [picture_description_1min.csv] already processed 90, skipping
# [picture_description_2min.csv] already processed 90, skipping
# [picture_description.csv] already processed 91, skipping
# [picture_description_1min.csv] already processed 91, skipping
# [picture_description_2min.csv] already processed 91, skipping
# [picture_description.csv] already processed 92, skipping
# [picture_description_1min.csv] already processed 92, skipping
# [picture_description_2min.csv] already processed 92, skipping
# [picture_description.csv] already processed 93, skipping
# [picture_description_1min.csv] already processed 93, skipping
# [picture_description_2min.csv] already processed 93, skipping
# [picture_description.csv] already processed 97, skipping
# [picture_description_1min.csv] already processed 97, skipping
# [picture_description_2min.csv] already processed 97, skipping
# [picture_description.csv] already processed 98, skipping
# [picture_description_1min.csv] already processed 98, skipping
# [picture_description_2min.csv] already processed 98, skipping
# [picture_description.csv] already processed 99, skipping
# [picture_description_1min.csv] already processed 99, skipping
# [picture_description_2min.csv] already processed 99, skipping
# [picture_description.csv] already processed 101, skipping
# [picture_description_1min.csv] already processed 101, skipping
# [picture_description_2min.csv] already processed 101, skipping
# [picture_description.csv] already processed 102, skipping
# [picture_description_1min.csv] already processed 102, skipping
# [picture_description_2min.csv] already processed 102, skipping
# [picture_description.csv] already processed 103, skipping
# [picture_description_1min.csv] already processed 103, skipping
# [picture_description_2min.csv] already processed 103, skipping
# [picture_description.csv] already processed 104, skipping
# [picture_description_1min.csv] already processed 104, skipping
# [picture_description_2min.csv] already processed 104, skipping
# [picture_description.csv] already processed 105, skipping
# [picture_description_1min.csv] already processed 105, skipping
# [picture_description_2min.csv] already processed 105, skipping
# [picture_description.csv] already processed 107, skipping
# [picture_description_1min.csv] already processed 107, skipping
# [picture_description_2min.csv] already processed 107, skipping
# [picture_description.csv] already processed 109, skipping
# [picture_description_1min.csv] already processed 109, skipping
# [picture_description_2min.csv] already processed 109, skipping
# [picture_description.csv] already processed 110, skipping
# [picture_description_1min.csv] already processed 110, skipping
# [picture_description_2min.csv] already processed 110, skipping
# [picture_description.csv] already processed 111, skipping
# [picture_description_1min.csv] already processed 111, skipping
# [picture_description_2min.csv] already processed 111, skipping
# [picture_description.csv] already processed 112, skipping
# [picture_description_1min.csv] already processed 112, skipping
# [picture_description_2min.csv] already processed 112, skipping
# [picture_description.csv] already processed 115, skipping
# [picture_description_1min.csv] already processed 115, skipping
# [picture_description_2min.csv] already processed 115, skipping
# [picture_description.csv] already processed 119, skipping
# [picture_description_1min.csv] already processed 119, skipping
# [picture_description_2min.csv] already processed 119, skipping
# [picture_description.csv] already processed 120, skipping
# [picture_description_1min.csv] already processed 120, skipping
# [picture_description_2min.csv] already processed 120, skipping
# [picture_description.csv] already processed 122, skipping
# [picture_description_1min.csv] already processed 122, skipping
# [picture_description_2min.csv] already processed 122, skipping
# [picture_description.csv] already processed 123, skipping
# [picture_description_1min.csv] already processed 123, skipping
# [picture_description_2min.csv] already processed 123, skipping
# [picture_description.csv] already processed 124, skipping
# [picture_description_1min.csv] already processed 124, skipping
# [picture_description_2min.csv] already processed 124, skipping
# [picture_description.csv] already processed 127, skipping
# [picture_description_1min.csv] already processed 127, skipping
# [picture_description_2min.csv] already processed 127, skipping
# [picture_description.csv] already processed 128, skipping
# [picture_description_1min.csv] already processed 128, skipping
# [picture_description_2min.csv] already processed 128, skipping
# [picture_description.csv] already processed 129, skipping
# [picture_description_1min.csv] already processed 129, skipping
# [picture_description_2min.csv] already processed 129, skipping
# [picture_description.csv] already processed 130, skipping
# [picture_description_1min.csv] already processed 130, skipping
# [picture_description_2min.csv] already processed 130, skipping
# [picture_description.csv] already processed 132, skipping
# [picture_description_1min.csv] already processed 132, skipping
# [picture_description_2min.csv] already processed 132, skipping
# [picture_description.csv] already processed 133, skipping
# [picture_description_1min.csv] already processed 133, skipping
# [picture_description_2min.csv] already processed 133, skipping
# [picture_description.csv] already processed 134, skipping
# [picture_description_1min.csv] already processed 134, skipping
# [picture_description_2min.csv] already processed 134, skipping
# [picture_description.csv] already processed 135, skipping
# [picture_description_1min.csv] already processed 135, skipping
# [picture_description_2min.csv] already processed 135, skipping
# [picture_description.csv] already processed 136, skipping
# [picture_description_1min.csv] already processed 136, skipping
# [picture_description_2min.csv] already processed 136, skipping
# [picture_description.csv] already processed 137, skipping
# [picture_description_1min.csv] already processed 137, skipping
# [picture_description_2min.csv] already processed 137, skipping
# [picture_description.csv] already processed 138, skipping
# [picture_description_1min.csv] already processed 138, skipping
# [picture_description_2min.csv] already processed 138, skipping
# [picture_description.csv] already processed 139, skipping
# [picture_description_1min.csv] already processed 139, skipping
# [picture_description_2min.csv] already processed 139, skipping
# [picture_description.csv] already processed 140, skipping
# [picture_description_1min.csv] already processed 140, skipping
# [picture_description_2min.csv] already processed 140, skipping
# [picture_description.csv] already processed 141, skipping
# [picture_description_1min.csv] already processed 141, skipping
# [picture_description_2min.csv] already processed 141, skipping
# [picture_description.csv] already processed 142, skipping
# [picture_description_1min.csv] already processed 142, skipping
# [picture_description_2min.csv] already processed 142, skipping
# [picture_description.csv] already processed 143, skipping
# [picture_description_1min.csv] already processed 143, skipping
# [picture_description_2min.csv] already processed 143, skipping
# [picture_description.csv] already processed 145, skipping
# [picture_description_1min.csv] already processed 145, skipping
# [picture_description_2min.csv] already processed 145, skipping
# [picture_description.csv] already processed 146, skipping
# [picture_description_1min.csv] already processed 146, skipping
# [picture_description_2min.csv] already processed 146, skipping
# [picture_description.csv] already processed 147, skipping
# [picture_description_1min.csv] already processed 147, skipping
# [picture_description_2min.csv] already processed 147, skipping
# [picture_description.csv] already processed 149, skipping
# [picture_description_1min.csv] already processed 149, skipping
# [picture_description_2min.csv] already processed 149, skipping
# [picture_description.csv] already processed 150, skipping
# [picture_description_1min.csv] already processed 150, skipping
# [picture_description_2min.csv] already processed 150, skipping
# [picture_description.csv] already processed 151, skipping
# [picture_description_1min.csv] already processed 151, skipping
# [picture_description_2min.csv] already processed 151, skipping
# [picture_description.csv] already processed 152, skipping
# [picture_description_1min.csv] already processed 152, skipping
# [picture_description_2min.csv] already processed 152, skipping
# [picture_description.csv] already processed 153, skipping
# [picture_description_1min.csv] already processed 153, skipping
# [picture_description_2min.csv] already processed 153, skipping
# [picture_description.csv] already processed 154, skipping
# [picture_description_1min.csv] already processed 154, skipping
# [picture_description_2min.csv] already processed 154, skipping
# [picture_description.csv] already processed 157, skipping
# [picture_description_1min.csv] already processed 157, skipping
# [picture_description_2min.csv] already processed 157, skipping
# [picture_description.csv] already processed 158, skipping
# [picture_description_1min.csv] already processed 158, skipping
# [picture_description_2min.csv] already processed 158, skipping
# [picture_description.csv] already processed 160, skipping
# [picture_description_1min.csv] already processed 160, skipping
# [picture_description_2min.csv] already processed 160, skipping
# [picture_description.csv] already processed 162, skipping
# [picture_description_1min.csv] already processed 162, skipping
# [picture_description_2min.csv] already processed 162, skipping
# [picture_description.csv] already processed 163, skipping
# [picture_description_1min.csv] already processed 163, skipping
# [picture_description_2min.csv] already processed 163, skipping
# [picture_description.csv] already processed 165, skipping
# [picture_description_1min.csv] already processed 165, skipping
# [picture_description_2min.csv] already processed 165, skipping
# [picture_description.csv] already processed 169, skipping
# [picture_description_1min.csv] already processed 169, skipping
# [picture_description_2min.csv] already processed 169, skipping
# [picture_description.csv] already processed 170, skipping
# [picture_description_1min.csv] already processed 170, skipping
# [picture_description_2min.csv] already processed 170, skipping
# [picture_description.csv] already processed 172, skipping
# [picture_description_1min.csv] already processed 172, skipping
# [picture_description_2min.csv] already processed 172, skipping
# [picture_description.csv] already processed 173, skipping
# [picture_description_1min.csv] already processed 173, skipping
# [picture_description_2min.csv] already processed 173, skipping
# [picture_description.csv] already processed 174, skipping
# [picture_description_1min.csv] already processed 174, skipping
# [picture_description_2min.csv] already processed 174, skipping
# [picture_description.csv] already processed 175, skipping
# [picture_description_1min.csv] already processed 175, skipping
# [picture_description_2min.csv] already processed 175, skipping
# [picture_description.csv] already processed 176, skipping
# [picture_description_1min.csv] already processed 176, skipping
# [picture_description_2min.csv] already processed 176, skipping
# [picture_description.csv] already processed 177, skipping
# [picture_description_1min.csv] already processed 177, skipping
# [picture_description_2min.csv] already processed 177, skipping
# [picture_description.csv] already processed 179, skipping
# [picture_description_1min.csv] already processed 179, skipping
# [picture_description_2min.csv] already processed 179, skipping
# [picture_description.csv] already processed 183, skipping
# [picture_description_1min.csv] already processed 183, skipping
# [picture_description_2min.csv] already processed 183, skipping
# [picture_description.csv] already processed 184, skipping
# [picture_description_1min.csv] already processed 184, skipping
# [picture_description_2min.csv] already processed 184, skipping
# [picture_description.csv] already processed 185, skipping
# [picture_description_1min.csv] already processed 185, skipping
# [picture_description_2min.csv] already processed 185, skipping
# [picture_description.csv] already processed 186, skipping
# [picture_description_1min.csv] already processed 186, skipping
# [picture_description_2min.csv] already processed 186, skipping
# [picture_description.csv] already processed 188, skipping
# [picture_description_1min.csv] already processed 188, skipping
# [picture_description_2min.csv] already processed 188, skipping
# [picture_description.csv] already processed 189, skipping
# [picture_description_1min.csv] already processed 189, skipping
# [picture_description_2min.csv] already processed 189, skipping
# [picture_description.csv] already processed 190, skipping
# [picture_description_1min.csv] already processed 190, skipping
# [picture_description_2min.csv] already processed 190, skipping
# [picture_description.csv] already processed 193, skipping
# [picture_description_1min.csv] already processed 193, skipping
# [picture_description_2min.csv] already processed 193, skipping
# [picture_description.csv] already processed 195, skipping
# [picture_description_1min.csv] already processed 195, skipping
# [picture_description_2min.csv] already processed 195, skipping
# [picture_description.csv] already processed 196, skipping
# [picture_description_1min.csv] already processed 196, skipping
# [picture_description_2min.csv] already processed 196, skipping
# [picture_description.csv] already processed 197, skipping
# [picture_description_1min.csv] already processed 197, skipping
# [picture_description_2min.csv] already processed 197, skipping
# [picture_description.csv] already processed 198, skipping
# [picture_description_1min.csv] already processed 198, skipping
# [picture_description_2min.csv] already processed 198, skipping
# [picture_description.csv] already processed 199, skipping
# [picture_description_1min.csv] already processed 199, skipping
# [picture_description_2min.csv] already processed 199, skipping
# [picture_description.csv] already processed 200, skipping
# [picture_description_1min.csv] already processed 200, skipping
# [picture_description_2min.csv] already processed 200, skipping
# [picture_description.csv] already processed 201, skipping
# [picture_description_1min.csv] already processed 201, skipping
# [picture_description_2min.csv] already processed 201, skipping
# [picture_description.csv] already processed 202, skipping
# [picture_description_1min.csv] already processed 202, skipping
# [picture_description_2min.csv] already processed 202, skipping
# [picture_description.csv] already processed 203, skipping
# [picture_description_1min.csv] already processed 203, skipping
# [picture_description_2min.csv] already processed 203, skipping
# [picture_description.csv] already processed 204, skipping
# [picture_description_1min.csv] already processed 204, skipping
# [picture_description_2min.csv] already processed 204, skipping
# [picture_description.csv] already processed 205, skipping
# [picture_description_1min.csv] already processed 205, skipping
# [picture_description_2min.csv] already processed 205, skipping
# [picture_description.csv] already processed 206, skipping
# [picture_description_1min.csv] already processed 206, skipping
# [picture_description_2min.csv] already processed 206, skipping
# [picture_description.csv] already processed 207, skipping
# [picture_description_1min.csv] already processed 207, skipping
# [picture_description_2min.csv] already processed 207, skipping
# [picture_description.csv] already processed 208, skipping
# [picture_description_1min.csv] already processed 208, skipping
# [picture_description_2min.csv] already processed 208, skipping
# [picture_description.csv] already processed 209, skipping
# [picture_description_1min.csv] already processed 209, skipping
# [picture_description_2min.csv] already processed 209, skipping
# [picture_description.csv] already processed 210, skipping
# [picture_description_1min.csv] already processed 210, skipping
# [picture_description_2min.csv] already processed 210, skipping
# [picture_description.csv] already processed 211, skipping
# [picture_description_1min.csv] already processed 211, skipping
# [picture_description_2min.csv] already processed 211, skipping
# [picture_description.csv] already processed 212, skipping
# [picture_description_1min.csv] already processed 212, skipping
# [picture_description_2min.csv] already processed 212, skipping
# [picture_description.csv] already processed 213, skipping
# [picture_description_1min.csv] already processed 213, skipping
# [picture_description_2min.csv] already processed 213, skipping
# [picture_description.csv] already processed 214, skipping
# [picture_description_1min.csv] already processed 214, skipping
# [picture_description_2min.csv] already processed 214, skipping
# [picture_description.csv] already processed 215, skipping
# [picture_description_1min.csv] already processed 215, skipping
# [picture_description_2min.csv] already processed 215, skipping
# [picture_description.csv] already processed 216, skipping
# [picture_description_1min.csv] already processed 216, skipping
# [picture_description_2min.csv] already processed 216, skipping
# [picture_description.csv] already processed 217, skipping
# [picture_description_1min.csv] already processed 217, skipping
# [picture_description_2min.csv] already processed 217, skipping
# [picture_description.csv] already processed 218, skipping
# [picture_description_1min.csv] already processed 218, skipping
# [picture_description_2min.csv] already processed 218, skipping
# [picture_description.csv] already processed 219, skipping
# [picture_description_1min.csv] already processed 219, skipping
# [picture_description_2min.csv] already processed 219, skipping
# [picture_description.csv] already processed 220, skipping
# [picture_description_1min.csv] already processed 220, skipping
# [picture_description_2min.csv] already processed 220, skipping
# [picture_description.csv] already processed 222, skipping
# [picture_description_1min.csv] already processed 222, skipping
# [picture_description_2min.csv] already processed 222, skipping
# [picture_description.csv] already processed 224, skipping
# [picture_description_1min.csv] already processed 224, skipping
# [picture_description_2min.csv] already processed 224, skipping
# [picture_description.csv] already processed 225, skipping
# [picture_description_1min.csv] already processed 225, skipping
# [picture_description_2min.csv] already processed 225, skipping
# [picture_description.csv] already processed 226, skipping
# [picture_description_1min.csv] already processed 226, skipping
# [picture_description_2min.csv] already processed 226, skipping
# [picture_description.csv] already processed 228, skipping
# [picture_description_1min.csv] already processed 228, skipping
# [picture_description_2min.csv] already processed 228, skipping
# [picture_description.csv] already processed 229, skipping
# [picture_description_1min.csv] already processed 229, skipping
# [picture_description_2min.csv] already processed 229, skipping
# [picture_description.csv] already processed 230, skipping
# [picture_description_1min.csv] already processed 230, skipping
# [picture_description_2min.csv] already processed 230, skipping
# [picture_description.csv] already processed 232, skipping
# [picture_description_1min.csv] already processed 232, skipping
# [picture_description_2min.csv] already processed 232, skipping
# [picture_description.csv] already processed 233, skipping
# [picture_description_1min.csv] already processed 233, skipping
# [picture_description_2min.csv] already processed 233, skipping
# [picture_description.csv] already processed 234, skipping
# [picture_description_1min.csv] already processed 234, skipping
# [picture_description_2min.csv] already processed 234, skipping
# [picture_description.csv] already processed 237, skipping
# [picture_description_1min.csv] already processed 237, skipping
# [picture_description_2min.csv] already processed 237, skipping
# [picture_description.csv] already processed 239, skipping
# [picture_description_1min.csv] already processed 239, skipping
# [picture_description_2min.csv] already processed 239, skipping
# [picture_description.csv] already processed 241, skipping
# [picture_description_1min.csv] already processed 241, skipping
# [picture_description_2min.csv] already processed 241, skipping
# [picture_description.csv] already processed 242, skipping
# [picture_description_1min.csv] already processed 242, skipping
# [picture_description_2min.csv] already processed 242, skipping
# [picture_description.csv] already processed 243, skipping
# [picture_description_1min.csv] already processed 243, skipping
# [picture_description_2min.csv] already processed 243, skipping
# [picture_description.csv] already processed 244, skipping
# [picture_description_1min.csv] already processed 244, skipping
# [picture_description_2min.csv] already processed 244, skipping
# [picture_description.csv] already processed 247, skipping
# [picture_description_1min.csv] already processed 247, skipping
# [picture_description_2min.csv] already processed 247, skipping
# [picture_description.csv] already processed 248, skipping
# [picture_description_1min.csv] already processed 248, skipping
# [picture_description_2min.csv] already processed 248, skipping
# [picture_description.csv] already processed 249, skipping
# [picture_description_1min.csv] already processed 249, skipping
# [picture_description_2min.csv] already processed 249, skipping
# [picture_description.csv] already processed 250, skipping
# [picture_description_1min.csv] already processed 250, skipping
# [picture_description_2min.csv] already processed 250, skipping
# [picture_description.csv] already processed 251, skipping
# [picture_description_1min.csv] already processed 251, skipping
# [picture_description_2min.csv] already processed 251, skipping
# [picture_description.csv] already processed 252, skipping
# [picture_description_1min.csv] already processed 252, skipping
# [picture_description_2min.csv] already processed 252, skipping
# [picture_description.csv] already processed 253, skipping
# [picture_description_1min.csv] already processed 253, skipping
# [picture_description_2min.csv] already processed 253, skipping
# [picture_description.csv] already processed 254, skipping
# [picture_description_1min.csv] already processed 254, skipping
# [picture_description_2min.csv] already processed 254, skipping
# [picture_description.csv] already processed 257, skipping
# [picture_description_1min.csv] already processed 257, skipping
# [picture_description_2min.csv] already processed 257, skipping
# [picture_description.csv] already processed 258, skipping
# [picture_description_1min.csv] already processed 258, skipping
# [picture_description_2min.csv] already processed 258, skipping
# [picture_description.csv] already processed 260, skipping
# [picture_description_1min.csv] already processed 260, skipping
# [picture_description_2min.csv] already processed 260, skipping
# [picture_description.csv] already processed 261, skipping
# [picture_description_1min.csv] already processed 261, skipping
# [picture_description_2min.csv] already processed 261, skipping
# [picture_description.csv] already processed 262, skipping
# [picture_description_1min.csv] already processed 262, skipping
# [picture_description_2min.csv] already processed 262, skipping
# [picture_description.csv] already processed 263, skipping
# [picture_description_1min.csv] already processed 263, skipping
# [picture_description_2min.csv] already processed 263, skipping
# [picture_description.csv] already processed 264, skipping
# [picture_description_1min.csv] already processed 264, skipping
# [picture_description_2min.csv] already processed 264, skipping
# [picture_description.csv] already processed 266, skipping
# [picture_description_1min.csv] already processed 266, skipping
# [picture_description_2min.csv] already processed 266, skipping
# [picture_description.csv] already processed 267, skipping
# [picture_description_1min.csv] already processed 267, skipping
# [picture_description_2min.csv] already processed 267, skipping
# [picture_description.csv] already processed 268, skipping
# [picture_description_1min.csv] already processed 268, skipping
# [picture_description_2min.csv] already processed 268, skipping
# [picture_description.csv] already processed 269, skipping
# [picture_description_1min.csv] already processed 269, skipping
# [picture_description_2min.csv] already processed 269, skipping
# [picture_description.csv] already processed 270, skipping
# [picture_description_1min.csv] already processed 270, skipping
# [picture_description_2min.csv] already processed 270, skipping
# [picture_description.csv] already processed 271, skipping
# [picture_description_1min.csv] already processed 271, skipping
# [picture_description_2min.csv] already processed 271, skipping
# [picture_description.csv] already processed 272, skipping
# [picture_description_1min.csv] already processed 272, skipping
# [picture_description_2min.csv] already processed 272, skipping
# [picture_description.csv] already processed 274, skipping
# [picture_description_1min.csv] already processed 274, skipping
# [picture_description_2min.csv] already processed 274, skipping
# [picture_description.csv] already processed 275, skipping
# [picture_description_1min.csv] already processed 275, skipping
# [picture_description_2min.csv] already processed 275, skipping
# [picture_description.csv] already processed 276, skipping
# [picture_description_1min.csv] already processed 276, skipping
# [picture_description_2min.csv] already processed 276, skipping
# [picture_description.csv] already processed 277, skipping
# [picture_description_1min.csv] already processed 277, skipping
# [picture_description_2min.csv] already processed 277, skipping
# [picture_description.csv] already processed 278, skipping
# [picture_description_1min.csv] already processed 278, skipping
# [picture_description_2min.csv] already processed 278, skipping
# [picture_description.csv] already processed 279, skipping
# [picture_description_1min.csv] already processed 279, skipping
# [picture_description_2min.csv] already processed 279, skipping
# [picture_description.csv] already processed 282, skipping
# [picture_description_1min.csv] already processed 282, skipping
# [picture_description_2min.csv] already processed 282, skipping
# [picture_description.csv] already processed 283, skipping
# [picture_description_1min.csv] already processed 283, skipping
# [picture_description_2min.csv] already processed 283, skipping
# [picture_description.csv] already processed 284, skipping
# [picture_description_1min.csv] already processed 284, skipping
# [picture_description_2min.csv] already processed 284, skipping
# [picture_description.csv] already processed 288, skipping
# [picture_description_1min.csv] already processed 288, skipping
# [picture_description_2min.csv] already processed 288, skipping
# [picture_description.csv] already processed 289, skipping
# [picture_description_1min.csv] already processed 289, skipping
# [picture_description_2min.csv] already processed 289, skipping
# [picture_description.csv] already processed 290, skipping
# [picture_description_1min.csv] already processed 290, skipping
# [picture_description_2min.csv] already processed 290, skipping
# [picture_description.csv] already processed 291, skipping
# [picture_description_1min.csv] already processed 291, skipping
# [picture_description_2min.csv] already processed 291, skipping
# [picture_description.csv] already processed 292, skipping
# [picture_description_1min.csv] already processed 292, skipping
# [picture_description_2min.csv] already processed 292, skipping
# [picture_description.csv] already processed 293, skipping
# [picture_description_1min.csv] already processed 293, skipping
# [picture_description_2min.csv] already processed 293, skipping
# [picture_description.csv] already processed 294, skipping
# [picture_description_1min.csv] already processed 294, skipping
# [picture_description_2min.csv] already processed 294, skipping
# [picture_description.csv] already processed 295, skipping
# [picture_description_1min.csv] already processed 295, skipping
# [picture_description_2min.csv] already processed 295, skipping
# [picture_description.csv] already processed 297, skipping
# [picture_description_1min.csv] already processed 297, skipping
# [picture_description_2min.csv] already processed 297, skipping
# [picture_description.csv] already processed 298, skipping
# [picture_description_1min.csv] already processed 298, skipping
# [picture_description_2min.csv] already processed 298, skipping
# [picture_description.csv] already processed 300, skipping
# [picture_description_1min.csv] already processed 300, skipping
# [picture_description_2min.csv] already processed 300, skipping
# [picture_description.csv] already processed 301, skipping
# [picture_description_1min.csv] already processed 301, skipping
# [picture_description_2min.csv] already processed 301, skipping
# [picture_description.csv] already processed 303, skipping
# [picture_description_1min.csv] already processed 303, skipping
# [picture_description_2min.csv] already processed 303, skipping
# [picture_description.csv] already processed 304, skipping
# [picture_description_1min.csv] already processed 304, skipping
# [picture_description_2min.csv] already processed 304, skipping
# [picture_description.csv] already processed 305, skipping
# [picture_description_1min.csv] already processed 305, skipping
# [picture_description_2min.csv] already processed 305, skipping
# [picture_description.csv] already processed 306, skipping
# [picture_description_1min.csv] already processed 306, skipping
# [picture_description_2min.csv] already processed 306, skipping
# [picture_description.csv] already processed 311, skipping
# [picture_description_1min.csv] already processed 311, skipping
# [picture_description_2min.csv] already processed 311, skipping
# [picture_description.csv] already processed 312, skipping
# [picture_description_1min.csv] already processed 312, skipping
# [picture_description_2min.csv] already processed 312, skipping
# [picture_description.csv] already processed 314, skipping
# [picture_description_1min.csv] already processed 314, skipping
# [picture_description_2min.csv] already processed 314, skipping
# [picture_description.csv] already processed 315, skipping
# [picture_description_1min.csv] already processed 315, skipping
# [picture_description_2min.csv] already processed 315, skipping
# [picture_description.csv] already processed 318, skipping
# [picture_description_1min.csv] already processed 318, skipping
# [picture_description_2min.csv] already processed 318, skipping
# [picture_description.csv] already processed 319, skipping
# [picture_description_1min.csv] already processed 319, skipping
# [picture_description_2min.csv] already processed 319, skipping
# [picture_description.csv] already processed 321, skipping
# [picture_description_1min.csv] already processed 321, skipping
# [picture_description_2min.csv] already processed 321, skipping
# [picture_description.csv] already processed 322, skipping
# [picture_description_1min.csv] already processed 322, skipping
# [picture_description_2min.csv] already processed 322, skipping
# [picture_description.csv] already processed 324, skipping
# [picture_description_1min.csv] already processed 324, skipping
# [picture_description_2min.csv] already processed 324, skipping
# [picture_description.csv] already processed 325, skipping
# [picture_description_1min.csv] already processed 325, skipping
# [picture_description_2min.csv] already processed 325, skipping
# [picture_description.csv] already processed 326, skipping
# [picture_description_1min.csv] already processed 326, skipping
# [picture_description_2min.csv] already processed 326, skipping
# [picture_description.csv] already processed 327, skipping
# [picture_description_1min.csv] already processed 327, skipping
# [picture_description_2min.csv] already processed 327, skipping
# [picture_description.csv] already processed 328, skipping
# [picture_description_1min.csv] already processed 328, skipping
# [picture_description_2min.csv] already processed 328, skipping
# [picture_description.csv] already processed 329, skipping
# [picture_description_1min.csv] already processed 329, skipping
# [picture_description_2min.csv] already processed 329, skipping
# [picture_description.csv] already processed 330, skipping
# [picture_description_1min.csv] already processed 330, skipping
# [picture_description_2min.csv] already processed 330, skipping
# [picture_description.csv] already processed 331, skipping
# [picture_description_1min.csv] already processed 331, skipping
# [picture_description_2min.csv] already processed 331, skipping
# [picture_description.csv] already processed 335, skipping
# [picture_description_1min.csv] already processed 335, skipping
# [picture_description_2min.csv] already processed 335, skipping
# [picture_description.csv] already processed 336, skipping
# [picture_description_1min.csv] already processed 336, skipping
# [picture_description_2min.csv] already processed 336, skipping
# [picture_description.csv] already processed 337, skipping
# [picture_description_1min.csv] already processed 337, skipping
# [picture_description_2min.csv] already processed 337, skipping
# [picture_description.csv] already processed 338, skipping
# [picture_description_1min.csv] already processed 338, skipping
# [picture_description_2min.csv] already processed 338, skipping
# [picture_description.csv] already processed 339, skipping
# [picture_description_1min.csv] already processed 339, skipping
# [picture_description_2min.csv] already processed 339, skipping
# [picture_description.csv] already processed 341, skipping
# [picture_description_1min.csv] already processed 341, skipping
# [picture_description_2min.csv] already processed 341, skipping
# [picture_description.csv] already processed 342, skipping
# [picture_description_1min.csv] already processed 342, skipping
# [picture_description_2min.csv] already processed 342, skipping
# [picture_description.csv] already processed 343, skipping
# [picture_description_1min.csv] already processed 343, skipping
# [picture_description_2min.csv] already processed 343, skipping
# [picture_description.csv] already processed 344, skipping
# [picture_description_1min.csv] already processed 344, skipping
# [picture_description_2min.csv] already processed 344, skipping
# [picture_description.csv] already processed 345, skipping
# [picture_description_1min.csv] already processed 345, skipping
# [picture_description_2min.csv] already processed 345, skipping
# [picture_description.csv] already processed 346, skipping
# [picture_description_1min.csv] already processed 346, skipping
# [picture_description_2min.csv] already processed 346, skipping
# [picture_description.csv] already processed 347, skipping
# [picture_description_1min.csv] already processed 347, skipping
# [picture_description_2min.csv] already processed 347, skipping
# [picture_description.csv] already processed 348, skipping
# [picture_description_1min.csv] already processed 348, skipping
# [picture_description_2min.csv] already processed 348, skipping
# [picture_description.csv] already processed 349, skipping
# [picture_description_1min.csv] already processed 349, skipping
# [picture_description_2min.csv] already processed 349, skipping
# [picture_description.csv] already processed 354, skipping
# [picture_description_1min.csv] already processed 354, skipping
# [picture_description_2min.csv] already processed 354, skipping
# [picture_description.csv] already processed 355, skipping
# [picture_description_1min.csv] already processed 355, skipping
# [picture_description_2min.csv] already processed 355, skipping
# [picture_description.csv] already processed 356, skipping
# [picture_description_1min.csv] already processed 356, skipping
# [picture_description_2min.csv] already processed 356, skipping
# [picture_description.csv] already processed 357, skipping
# [picture_description_1min.csv] already processed 357, skipping
# [picture_description_2min.csv] already processed 357, skipping
# [picture_description.csv] already processed 358, skipping
# [picture_description_1min.csv] already processed 358, skipping
# [picture_description_2min.csv] already processed 358, skipping
# [picture_description.csv] already processed 359, skipping
# [picture_description_1min.csv] already processed 359, skipping
# [picture_description_2min.csv] already processed 359, skipping
# [picture_description.csv] already processed 360, skipping
# [picture_description_1min.csv] already processed 360, skipping
# [picture_description_2min.csv] already processed 360, skipping
# [picture_description.csv] already processed 361, skipping
# [picture_description_1min.csv] already processed 361, skipping
# [picture_description_2min.csv] already processed 361, skipping
# [picture_description.csv] already processed 362, skipping
# [picture_description_1min.csv] already processed 362, skipping
# [picture_description_2min.csv] already processed 362, skipping
# [picture_description.csv] already processed 363, skipping
# [picture_description_1min.csv] already processed 363, skipping
# [picture_description_2min.csv] already processed 363, skipping
# [picture_description.csv] already processed 364, skipping
# [picture_description_1min.csv] already processed 364, skipping
# [picture_description_2min.csv] already processed 364, skipping
# [picture_description.csv] already processed 365, skipping
# [picture_description_1min.csv] already processed 365, skipping
# [picture_description_2min.csv] already processed 365, skipping
# [picture_description.csv] already processed 366, skipping
# [picture_description_1min.csv] already processed 366, skipping
# [picture_description_2min.csv] already processed 366, skipping
# [picture_description.csv] already processed 367, skipping
# [picture_description_1min.csv] already processed 367, skipping
# [picture_description_2min.csv] already processed 367, skipping
# [picture_description.csv] already processed 368, skipping
# [picture_description_1min.csv] already processed 368, skipping
# [picture_description_2min.csv] already processed 368, skipping
# [picture_description.csv] already processed 369, skipping
# [picture_description_1min.csv] already processed 369, skipping
# [picture_description_2min.csv] already processed 369, skipping
# [picture_description.csv] already processed 371, skipping
# [picture_description_1min.csv] already processed 371, skipping
# [picture_description_2min.csv] already processed 371, skipping
# [picture_description.csv] already processed 372, skipping
# [picture_description_1min.csv] already processed 372, skipping
# [picture_description_2min.csv] already processed 372, skipping
# [picture_description.csv] already processed 373, skipping
# [picture_description_1min.csv] already processed 373, skipping
# [picture_description_2min.csv] already processed 373, skipping
# [picture_description.csv] already processed 374, skipping
# [picture_description_1min.csv] already processed 374, skipping
# [picture_description_2min.csv] already processed 374, skipping
# [picture_description.csv] already processed 375, skipping
# [picture_description_1min.csv] already processed 375, skipping
# [picture_description_2min.csv] already processed 375, skipping
# [picture_description.csv] already processed 376, skipping
# [picture_description_1min.csv] already processed 376, skipping
# [picture_description_2min.csv] already processed 376, skipping
# [picture_description.csv] already processed 377, skipping
# [picture_description_1min.csv] already processed 377, skipping
# [picture_description_2min.csv] already processed 377, skipping
# [picture_description.csv] already processed 378, skipping
# [picture_description_1min.csv] already processed 378, skipping
# [picture_description_2min.csv] already processed 378, skipping
# [picture_description.csv] already processed 379, skipping
# [picture_description_1min.csv] already processed 379, skipping
# [picture_description_2min.csv] already processed 379, skipping
# [picture_description.csv] already processed 381, skipping
# [picture_description_1min.csv] already processed 381, skipping
# [picture_description_2min.csv] already processed 381, skipping
# [picture_description.csv] already processed 382, skipping
# [picture_description_1min.csv] already processed 382, skipping
# [picture_description_2min.csv] already processed 382, skipping
# [picture_description.csv] already processed 384, skipping
# [picture_description_1min.csv] already processed 384, skipping
# [picture_description_2min.csv] already processed 384, skipping
# [picture_description.csv] already processed 385, skipping
# [picture_description_1min.csv] already processed 385, skipping
# [picture_description_2min.csv] already processed 385, skipping
# [picture_description.csv] already processed 386, skipping
# [picture_description_1min.csv] already processed 386, skipping
# [picture_description_2min.csv] already processed 386, skipping
# [picture_description.csv] already processed 387, skipping
# [picture_description_1min.csv] already processed 387, skipping
# [picture_description_2min.csv] already processed 387, skipping
# [picture_description.csv] already processed 388, skipping
# [picture_description_1min.csv] already processed 388, skipping
# [picture_description_2min.csv] already processed 388, skipping
# [picture_description.csv] already processed 389, skipping
# [picture_description_1min.csv] already processed 389, skipping
# [picture_description_2min.csv] already processed 389, skipping
# [picture_description.csv] already processed 390, skipping
# [picture_description_1min.csv] already processed 390, skipping
# [picture_description_2min.csv] already processed 390, skipping
# [picture_description.csv] already processed 392, skipping
# [picture_description_1min.csv] already processed 392, skipping
# [picture_description_2min.csv] already processed 392, skipping
# [picture_description.csv] already processed 393, skipping
# [picture_description_1min.csv] already processed 393, skipping
# [picture_description_2min.csv] already processed 393, skipping
# [picture_description.csv] already processed 394, skipping
# [picture_description_1min.csv] already processed 394, skipping
# [picture_description_2min.csv] already processed 394, skipping
# [picture_description.csv] already processed 395, skipping
# [picture_description_1min.csv] already processed 395, skipping
# [picture_description_2min.csv] already processed 395, skipping
# [picture_description.csv] already processed 396, skipping
# [picture_description_1min.csv] already processed 396, skipping
# [picture_description_2min.csv] already processed 396, skipping
# [picture_description.csv] already processed 397, skipping
# [picture_description_1min.csv] already processed 397, skipping
# [picture_description_2min.csv] already processed 397, skipping
# [picture_description.csv] already processed 399, skipping
# [picture_description_1min.csv] already processed 399, skipping
# [picture_description_2min.csv] already processed 399, skipping
# [picture_description.csv] already processed 400, skipping
# [picture_description_1min.csv] already processed 400, skipping
# [picture_description_2min.csv] already processed 400, skipping
# [picture_description.csv] already processed 401, skipping
# [picture_description_1min.csv] already processed 401, skipping
# [picture_description_2min.csv] already processed 401, skipping
# [picture_description.csv] already processed 402, skipping
# [picture_description_1min.csv] already processed 402, skipping
# [picture_description_2min.csv] already processed 402, skipping
# [picture_description.csv] already processed 403, skipping
# [picture_description_1min.csv] already processed 403, skipping
# [picture_description_2min.csv] already processed 403, skipping
# [picture_description.csv] already processed 404, skipping
# [picture_description_1min.csv] already processed 404, skipping
# [picture_description_2min.csv] already processed 404, skipping
# [picture_description.csv] already processed 406, skipping
# [picture_description_1min.csv] already processed 406, skipping
# [picture_description_2min.csv] already processed 406, skipping
# [picture_description.csv] already processed 407, skipping
# [picture_description_1min.csv] already processed 407, skipping
# [picture_description_2min.csv] already processed 407, skipping
# [picture_description.csv] already processed 409, skipping
# [picture_description_1min.csv] already processed 409, skipping
# [picture_description_2min.csv] already processed 409, skipping
# [picture_description.csv] already processed 410, skipping
# [picture_description_1min.csv] already processed 410, skipping
# [picture_description_2min.csv] already processed 410, skipping
# [picture_description.csv] already processed 411, skipping
# [picture_description_1min.csv] already processed 411, skipping
# [picture_description_2min.csv] already processed 411, skipping
# [picture_description.csv] already processed 415, skipping
# [picture_description_1min.csv] already processed 415, skipping
# [picture_description_2min.csv] already processed 415, skipping
# [picture_description.csv] already processed 416, skipping
# [picture_description_1min.csv] already processed 416, skipping
# [picture_description_2min.csv] already processed 416, skipping
# [picture_description.csv] already processed 417, skipping
# [picture_description_1min.csv] already processed 417, skipping
# [picture_description_2min.csv] already processed 417, skipping
# [picture_description.csv] already processed 419, skipping
# [picture_description_1min.csv] already processed 419, skipping
# [picture_description_2min.csv] already processed 419, skipping
# ...
# [picture_description.csv] processing 1245 (cap=300s)
# [picture_description_1min.csv] processing 1245 (cap=60s)
# [picture_description_2min.csv] processing 1245 (cap=120s)
# [picture_description.csv] processing 1246 (cap=300s)
# [picture_description_1min.csv] processing 1246 (cap=60s)
# [picture_description_2min.csv] processing 1246 (cap=120s)
# [picture_description.csv] processing 1247 (cap=300s)
# [picture_description_1min.csv] processing 1247 (cap=60s)
# [picture_description_2min.csv] processing 1247 (cap=120s)
# [picture_description.csv] processing 1248 (cap=300s)
# [picture_description_1min.csv] processing 1248 (cap=60s)
# [picture_description_2min.csv] processing 1248 (cap=120s)
# [picture_description.csv] processing 1249 (cap=300s)
# [picture_description_1min.csv] processing 1249 (cap=60s)
# [picture_description_2min.csv] processing 1249 (cap=120s)
# [picture_description.csv] processing 1250 (cap=300s)
# [picture_description_1min.csv] processing 1250 (cap=60s)
# [picture_description_2min.csv] processing 1250 (cap=120s)
# [picture_description.csv] processing 1251 (cap=300s)
# [picture_description_1min.csv] processing 1251 (cap=60s)
# [picture_description_2min.csv] processing 1251 (cap=120s)
# [picture_description.csv] processing 1252 (cap=300s)
# [picture_description_1min.csv] processing 1252 (cap=60s)
# [picture_description_2min.csv] processing 1252 (cap=120s)
# [picture_description.csv] processing 1253 (cap=300s)
# [picture_description_1min.csv] processing 1253 (cap=60s)
# [picture_description_2min.csv] processing 1253 (cap=120s)
# [picture_description.csv] processing 1254 (cap=300s)
# [picture_description_1min.csv] processing 1254 (cap=60s)
# [picture_description_2min.csv] processing 1254 (cap=120s)
# [picture_description.csv] processing 1255 (cap=300s)
# [picture_description_1min.csv] processing 1255 (cap=60s)
# [picture_description_2min.csv] processing 1255 (cap=120s)
# [picture_description.csv] processing 1257 (cap=300s)
# [picture_description_1min.csv] processing 1257 (cap=60s)
# [picture_description_2min.csv] processing 1257 (cap=120s)
# [picture_description.csv] processing 1258 (cap=300s)
# [picture_description_1min.csv] processing 1258 (cap=60s)
# [picture_description_2min.csv] processing 1258 (cap=120s)
# [picture_description.csv] processing 1264 (cap=300s)
# [picture_description_1min.csv] processing 1264 (cap=60s)
# [picture_description_2min.csv] processing 1264 (cap=120s)
# [picture_description.csv] processing 1266 (cap=300s)
# [picture_description_1min.csv] processing 1266 (cap=60s)
# [picture_description_2min.csv] processing 1266 (cap=120s)
# [picture_description.csv] processing 1267 (cap=300s)
# [picture_description_1min.csv] processing 1267 (cap=60s)
# [picture_description_2min.csv] processing 1267 (cap=120s)
# [picture_description.csv] processing 1268 (cap=300s)
# [picture_description_1min.csv] processing 1268 (cap=60s)
# [picture_description_2min.csv] processing 1268 (cap=120s)
# [picture_description.csv] processing 1271 (cap=300s)
# [picture_description_1min.csv] processing 1271 (cap=60s)
# [picture_description_2min.csv] processing 1271 (cap=120s)
# [picture_description.csv] processing 1274 (cap=300s)
# [picture_description_1min.csv] processing 1274 (cap=60s)
# [picture_description_2min.csv] processing 1274 (cap=120s)
# [picture_description.csv] processing 1275 (cap=300s)
# [picture_description_1min.csv] processing 1275 (cap=60s)
# [picture_description_2min.csv] processing 1275 (cap=120s)
# [picture_description.csv] processing 1276 (cap=300s)
# [picture_description_1min.csv] processing 1276 (cap=60s)
# [picture_description_2min.csv] processing 1276 (cap=120s)
# [picture_description.csv] processing 1277 (cap=300s)
# [picture_description_1min.csv] processing 1277 (cap=60s)
# [picture_description_2min.csv] processing 1277 (cap=120s)
# [picture_description.csv] processing 1278 (cap=300s)
# [picture_description_1min.csv] processing 1278 (cap=60s)
# [picture_description_2min.csv] processing 1278 (cap=120s)
# [picture_description.csv] processing 1280 (cap=300s)
# [picture_description_1min.csv] processing 1280 (cap=60s)
# [picture_description_2min.csv] processing 1280 (cap=120s)
# [picture_description.csv] processing 1281 (cap=300s)
# [picture_description_1min.csv] processing 1281 (cap=60s)
# [picture_description_2min.csv] processing 1281 (cap=120s)
# [picture_description.csv] processing 1282 (cap=300s)
# [picture_description_1min.csv] processing 1282 (cap=60s)
# [picture_description_2min.csv] processing 1282 (cap=120s)
# [picture_description.csv] processing 1283 (cap=300s)
# [picture_description_1min.csv] processing 1283 (cap=60s)
# [picture_description_2min.csv] processing 1283 (cap=120s)
# [picture_description.csv] processing 1284 (cap=300s)
# [picture_description_1min.csv] processing 1284 (cap=60s)
# [picture_description_2min.csv] processing 1284 (cap=120s)
# [picture_description.csv] processing 1285 (cap=300s)
# [picture_description_1min.csv] processing 1285 (cap=60s)
# [picture_description_2min.csv] processing 1285 (cap=120s)
# [picture_description.csv] processing 1286 (cap=300s)
# [picture_description_1min.csv] processing 1286 (cap=60s)
# [picture_description_2min.csv] processing 1286 (cap=120s)
# [picture_description.csv] processing 1288 (cap=300s)
# [picture_description_1min.csv] processing 1288 (cap=60s)
# [picture_description_2min.csv] processing 1288 (cap=120s)
# [picture_description.csv] processing 1290 (cap=300s)
# [picture_description_1min.csv] processing 1290 (cap=60s)
# [picture_description_2min.csv] processing 1290 (cap=120s)
# [picture_description.csv] processing 1291 (cap=300s)
# [picture_description_1min.csv] processing 1291 (cap=60s)
# [picture_description_2min.csv] processing 1291 (cap=120s)
# [picture_description.csv] processing 1292 (cap=300s)
# [picture_description_1min.csv] processing 1292 (cap=60s)
# [picture_description_2min.csv] processing 1292 (cap=120s)
# [picture_description.csv] processing 1293 (cap=300s)
# [picture_description_1min.csv] processing 1293 (cap=60s)
# [picture_description_2min.csv] processing 1293 (cap=120s)
# [picture_description.csv] processing 1294 (cap=300s)
# [picture_description_1min.csv] processing 1294 (cap=60s)
# [picture_description_2min.csv] processing 1294 (cap=120s)
# [picture_description.csv] processing 1295 (cap=300s)
# [picture_description_1min.csv] processing 1295 (cap=60s)
# [picture_description_2min.csv] processing 1295 (cap=120s)
# [picture_description.csv] processing 1297 (cap=300s)
# [picture_description_1min.csv] processing 1297 (cap=60s)
# [picture_description_2min.csv] processing 1297 (cap=120s)
# [picture_description.csv] processing 1298 (cap=300s)
# [picture_description_1min.csv] processing 1298 (cap=60s)
# [picture_description_2min.csv] processing 1298 (cap=120s)
# [picture_description.csv] processing 1299 (cap=300s)
# [picture_description_1min.csv] processing 1299 (cap=60s)
# [picture_description_2min.csv] processing 1299 (cap=120s)
# [picture_description.csv] processing 1302 (cap=300s)
# [picture_description_1min.csv] processing 1302 (cap=60s)
# [picture_description_2min.csv] processing 1302 (cap=120s)
# [picture_description.csv] processing 1304 (cap=300s)
# [picture_description_1min.csv] processing 1304 (cap=60s)
# [picture_description_2min.csv] processing 1304 (cap=120s)
# [picture_description.csv] processing 1305 (cap=300s)
# [picture_description_1min.csv] processing 1305 (cap=60s)
# [picture_description_2min.csv] processing 1305 (cap=120s)
# [picture_description.csv] processing 1308 (cap=300s)
# [picture_description_1min.csv] processing 1308 (cap=60s)
# [picture_description_2min.csv] processing 1308 (cap=120s)
# [picture_description.csv] processing 1309 (cap=300s)
# [picture_description_1min.csv] processing 1309 (cap=60s)
# [picture_description_2min.csv] processing 1309 (cap=120s)
# [picture_description.csv] processing 1310 (cap=300s)
# [picture_description_1min.csv] processing 1310 (cap=60s)
# [picture_description_2min.csv] processing 1310 (cap=120s)
# [picture_description.csv] processing 1311 (cap=300s)
# [picture_description_1min.csv] processing 1311 (cap=60s)
# [picture_description_2min.csv] processing 1311 (cap=120s)
# [picture_description.csv] processing 1312 (cap=300s)
# [picture_description_1min.csv] processing 1312 (cap=60s)
# [picture_description_2min.csv] processing 1312 (cap=120s)
# [picture_description.csv] processing 1313 (cap=300s)
# [picture_description_1min.csv] processing 1313 (cap=60s)
# [picture_description_2min.csv] processing 1313 (cap=120s)
# [picture_description.csv] processing 1314 (cap=300s)
# [picture_description_1min.csv] processing 1314 (cap=60s)
# [picture_description_2min.csv] processing 1314 (cap=120s)
# [picture_description.csv] processing 1315 (cap=300s)
# [picture_description_1min.csv] processing 1315 (cap=60s)
# [picture_description_2min.csv] processing 1315 (cap=120s)
# [picture_description.csv] processing 1316 (cap=300s)
# [picture_description_1min.csv] processing 1316 (cap=60s)
# [picture_description_2min.csv] processing 1316 (cap=120s)
# [picture_description.csv] processing 1317 (cap=300s)
# [picture_description_1min.csv] processing 1317 (cap=60s)
# [picture_description_2min.csv] processing 1317 (cap=120s)
# [picture_description.csv] processing 1318 (cap=300s)
# [picture_description_1min.csv] processing 1318 (cap=60s)
# [picture_description_2min.csv] processing 1318 (cap=120s)
# [picture_description.csv] processing 1319 (cap=300s)
# [picture_description_1min.csv] processing 1319 (cap=60s)
# [picture_description_2min.csv] processing 1319 (cap=120s)
# [picture_description.csv] processing 1320 (cap=300s)
# [picture_description_1min.csv] processing 1320 (cap=60s)
# [picture_description_2min.csv] processing 1320 (cap=120s)
# [picture_description.csv] processing 1322 (cap=300s)
# [picture_description_1min.csv] processing 1322 (cap=60s)
# [picture_description_2min.csv] processing 1322 (cap=120s)
# [picture_description.csv] processing 1324 (cap=300s)
# [picture_description_1min.csv] processing 1324 (cap=60s)
# [picture_description_2min.csv] processing 1324 (cap=120s)
# [picture_description.csv] processing 1325 (cap=300s)
# [picture_description_1min.csv] processing 1325 (cap=60s)
# [picture_description_2min.csv] processing 1325 (cap=120s)
# [picture_description.csv] processing 1326 (cap=300s)
# [picture_description_1min.csv] processing 1326 (cap=60s)
# [picture_description_2min.csv] processing 1326 (cap=120s)
# [picture_description.csv] processing 1327 (cap=300s)
# [picture_description_1min.csv] processing 1327 (cap=60s)
# [picture_description_2min.csv] processing 1327 (cap=120s)
# [picture_description.csv] processing 1328 (cap=300s)
# [picture_description_1min.csv] processing 1328 (cap=60s)
# [picture_description_2min.csv] processing 1328 (cap=120s)
# [picture_description.csv] processing 1330 (cap=300s)
# [picture_description_1min.csv] processing 1330 (cap=60s)
# [picture_description_2min.csv] processing 1330 (cap=120s)
# [picture_description.csv] processing 1331 (cap=300s)
# [picture_description_1min.csv] processing 1331 (cap=60s)
# [picture_description_2min.csv] processing 1331 (cap=120s)
# [picture_description.csv] processing 1332 (cap=300s)
# [picture_description_1min.csv] processing 1332 (cap=60s)
# [picture_description_2min.csv] processing 1332 (cap=120s)
# [picture_description.csv] processing 1334 (cap=300s)
# [picture_description_1min.csv] processing 1334 (cap=60s)
# [picture_description_2min.csv] processing 1334 (cap=120s)
# [picture_description.csv] processing 1336 (cap=300s)
# [picture_description_1min.csv] processing 1336 (cap=60s)
# [picture_description_2min.csv] processing 1336 (cap=120s)
# [picture_description.csv] processing 1339 (cap=300s)
# [picture_description_1min.csv] processing 1339 (cap=60s)
# [picture_description_2min.csv] processing 1339 (cap=120s)
# [picture_description.csv] processing 1340 (cap=300s)
# [picture_description_1min.csv] processing 1340 (cap=60s)
# [picture_description_2min.csv] processing 1340 (cap=120s)
# [picture_description.csv] processing 1341 (cap=300s)
# [picture_description_1min.csv] processing 1341 (cap=60s)
# [picture_description_2min.csv] processing 1341 (cap=120s)
# [picture_description.csv] processing 1344 (cap=300s)
# [picture_description_1min.csv] processing 1344 (cap=60s)
# [picture_description_2min.csv] processing 1344 (cap=120s)
# [picture_description.csv] processing 1346 (cap=300s)
# [picture_description_1min.csv] processing 1346 (cap=60s)
# [picture_description_2min.csv] processing 1346 (cap=120s)
# [picture_description.csv] processing 1347 (cap=300s)
# [picture_description_1min.csv] processing 1347 (cap=60s)
# [picture_description_2min.csv] processing 1347 (cap=120s)
# [picture_description.csv] processing 1348 (cap=300s)
# [picture_description_1min.csv] processing 1348 (cap=60s)
# [picture_description_2min.csv] processing 1348 (cap=120s)
# [picture_description.csv] processing 1349 (cap=300s)
# [picture_description_1min.csv] processing 1349 (cap=60s)
# [picture_description_2min.csv] processing 1349 (cap=120s)
# [picture_description.csv] processing 1350 (cap=300s)
# [picture_description_1min.csv] processing 1350 (cap=60s)
# [picture_description_2min.csv] processing 1350 (cap=120s)
# [picture_description.csv] processing 1351 (cap=300s)
# [picture_description_1min.csv] processing 1351 (cap=60s)
# [picture_description_2min.csv] processing 1351 (cap=120s)
# [picture_description.csv] processing 1353 (cap=300s)
# [picture_description_1min.csv] processing 1353 (cap=60s)
# [picture_description_2min.csv] processing 1353 (cap=120s)
# [picture_description.csv] processing 1354 (cap=300s)
# [picture_description_1min.csv] processing 1354 (cap=60s)
# [picture_description_2min.csv] processing 1354 (cap=120s)
# [picture_description.csv] processing 1355 (cap=300s)
# [picture_description_1min.csv] processing 1355 (cap=60s)
# [picture_description_2min.csv] processing 1355 (cap=120s)
# [picture_description.csv] processing 1356 (cap=300s)
# [picture_description_1min.csv] processing 1356 (cap=60s)
# [picture_description_2min.csv] processing 1356 (cap=120s)
# [picture_description.csv] processing 1357 (cap=300s)
# [picture_description_1min.csv] processing 1357 (cap=60s)
# [picture_description_2min.csv] processing 1357 (cap=120s)
# [picture_description.csv] processing 1358 (cap=300s)
# [picture_description_1min.csv] processing 1358 (cap=60s)
# [picture_description_2min.csv] processing 1358 (cap=120s)
# [picture_description.csv] processing 1359 (cap=300s)
# [picture_description_1min.csv] processing 1359 (cap=60s)
# [picture_description_2min.csv] processing 1359 (cap=120s)
# [picture_description.csv] processing 1360 (cap=300s)
# [picture_description_1min.csv] processing 1360 (cap=60s)
# [picture_description_2min.csv] processing 1360 (cap=120s)
# [picture_description.csv] processing 1361 (cap=300s)
# [picture_description_1min.csv] processing 1361 (cap=60s)
# [picture_description_2min.csv] processing 1361 (cap=120s)
# [picture_description.csv] processing 1362 (cap=300s)
# [picture_description_1min.csv] processing 1362 (cap=60s)
# [picture_description_2min.csv] processing 1362 (cap=120s)
# [picture_description.csv] processing 1363 (cap=300s)
# [picture_description_1min.csv] processing 1363 (cap=60s)
# [picture_description_2min.csv] processing 1363 (cap=120s)
# [picture_description.csv] processing 1365 (cap=300s)
# [picture_description_1min.csv] processing 1365 (cap=60s)
# [picture_description_2min.csv] processing 1365 (cap=120s)
# [picture_description.csv] processing 1366 (cap=300s)
# [picture_description_1min.csv] processing 1366 (cap=60s)
# [picture_description_2min.csv] processing 1366 (cap=120s)
# [picture_description.csv] processing 1368 (cap=300s)
# [picture_description_1min.csv] processing 1368 (cap=60s)
# [picture_description_2min.csv] processing 1368 (cap=120s)
# [picture_description.csv] processing 1369 (cap=300s)
# [picture_description_1min.csv] processing 1369 (cap=60s)
# [picture_description_2min.csv] processing 1369 (cap=120s)
# [picture_description.csv] processing 1370 (cap=300s)
# [picture_description_1min.csv] processing 1370 (cap=60s)
# [picture_description_2min.csv] processing 1370 (cap=120s)
#
# Done. Wrote/updated:
#  - /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/picture_description.csv
#  - /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/picture_description_1min.csv
#  - /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/picture_description_2min.csv
