# %%
# setup
import sys

# add project root
sys.path.append("/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/src")

from feature_extraction.features import nid_ratio, tokenize, clean_text

import importlib
importlib.reload(nid_ratio)

from feature_extraction.features.nid_ratio import nid_ratio
# Out:
# [nltk_data] Downloading package words to /Users/gilanorup/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package words to /Users/gilanorup/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
test_text = "Today I went to the market and bought apples, oranges, and thingamajigs. I don't know what they are."

# %%
text = clean_text(test_text)
print(text)

# %%
tokenized = tokenize(text)
print(tokenized)

# %%
result = nid_ratio(test_text)
print(f"NID ratio: {result}")
# Out:
# NID ratio: 0.05555555555555555
