# %% [markdown]
# combined picture-description (cookieTheft + picnicScene) features, random order for tasks
# 1min, 2min and ≥5min version

# %%
import os, sys, contextlib, wave, tempfile, json
import random, hashlib
import pandas as pd
from pydub import AudioSegment

# project root
sys.path.append("/Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/src")

from config.constants import DATA_DIRECTORY, GIT_DIRECTORY

# linguistic features
from feature_extraction.features import (
    n_words, pos_ratios_spacy, filler_word_ratio, ttr, mattr, avg_word_length,
    light_verb_ratio, empty_word_ratio, nid_ratio, adjacent_repetitions,
    brunets_index, honores_statistic, guirauds_statistic
)
from feature_extraction.features.psycholinguistic_features import (
    compute_avg_by_pos, load_aoa_lexicon, load_imageability_norms,
    load_familiarity_norms, load_frequency_norms, load_concreteness_lexicon
)
from feature_extraction.features.fluency_features import calculate_fluency_features

# audio features
from feature_extraction.audio import (
    extract_acoustic_features as base_extract_acoustic_features,
    extract_egemaps as base_extract_egemaps,
)

# article-pause-contentword
from feature_extraction.features.article_pause_contentword import article_pause_contentword

# config

PICTURE_TASKS = ["cookieTheft", "picnicScene"]
TIMESTAMP_ROOT = "/Volumes/g_psyplafor_methlab$/Students/Gila/word_timestamps"
OUT_DIR = os.path.join(GIT_DIRECTORY, "results", "features")

OUTPUTS = {
    "picture_description.csv":        300,  # 5:00
    "picture_description_1min.csv":   60,   # 1:00
    "picture_description_2min.csv":   120,  # 2:00
}

# small helpers

def _infer_wav_duration_seconds(wav_path: str):
    try:
        with contextlib.closing(wave.open(wav_path, 'r')) as w:
            return w.getnframes() / float(w.getframerate())
    except Exception:
        return None

def load_transcriptions(subject_folder):
    p = os.path.join(subject_folder, "ASR", "transcriptions.csv")
    return pd.read_csv(p) if os.path.exists(p) else pd.DataFrame()

def load_audio_durations(subject_folder):
    p = os.path.join(subject_folder, "audio_durations.csv")
    return pd.read_csv(p) if os.path.exists(p) else pd.DataFrame()

def load_task_word_timestamps(subject_id: str, task: str) -> pd.DataFrame | None:
    p = os.path.join(TIMESTAMP_ROOT, task, "google", "timestamps", f"{subject_id}.csv")
    if not os.path.exists(p):
        return None
    df = pd.read_csv(p)
    need = ["word", "start", "end"]
    if not all(c in df.columns for c in need):
        return None
    df = df[need].copy()
    df["start"] = pd.to_numeric(df["start"], errors="coerce")
    df["end"]   = pd.to_numeric(df["end"], errors="coerce")
    df = df.dropna(subset=["word", "start", "end"])
    return df

def load_audio_file(subject_folder, task):
    p = os.path.join(subject_folder, f"{task}.wav")
    return p if os.path.exists(p) else None

def extract_acoustic_features(audio_path=None, text=None, duration=None, audio_segment=None):
    if audio_segment is not None:
        tmp_path = os.path.join(tempfile.gettempdir(), "tmp_picdesc_audio.wav")
        audio_segment.export(tmp_path, format="wav")
        return base_extract_acoustic_features(tmp_path, text, duration)
    return base_extract_acoustic_features(audio_path, text, duration)

def extract_egemaps(audio_path=None, audio_segment=None):
    if audio_segment is not None:
        tmp_path = os.path.join(tempfile.gettempdir(), "tmp_picdesc_audio.wav")
        audio_segment.export(tmp_path, format="wav")
        return base_extract_egemaps(tmp_path)
    return base_extract_egemaps(audio_path)

# append + checkpoint

def append_row_atomic(out_path: str, row_df: pd.DataFrame):
    exists = os.path.exists(out_path)
    # append one row; write header only if new file
    row_df.to_csv(out_path, mode="a", header=not exists, index=False)
    # extra safety: force flush to disk
    with open(out_path, "a") as f:
        f.flush()
        os.fsync(f.fileno())

def load_checkpoint(ckpt_path: str) -> set[str]:
    if not os.path.exists(ckpt_path):
        return set()
    try:
        with open(ckpt_path, "r") as f:
            return set(json.load(f))
    except Exception:
        return set()

def save_checkpoint(ckpt_path: str, processed_ids: set[str]):
    tmp = ckpt_path + ".tmp"
    with open(tmp, "w") as f:
        json.dump(sorted(processed_ids), f)
        f.flush()
        os.fsync(f.fileno())
    os.replace(tmp, ckpt_path)  # atomic rename

# reproducible random order

def task_order_for_subject(subject_id: str, base_tasks=None, seed: int | None = None):
    """
    Return a reproducible shuffle of tasks for a subject.
    """
    if base_tasks is None:
        base_tasks = PICTURE_TASKS
    tasks = list(base_tasks)

    env_seed = os.environ.get("PICTURE_TASKS_SEED")
    if env_seed is not None and env_seed.strip():
        seed = int(env_seed)

    if seed is None:
        # stable across runs/machines for this subject_id
        seed = int(hashlib.sha1(str(subject_id).encode()).hexdigest(), 16) % (10**8)

    rng = random.Random(seed)
    rng.shuffle(tasks)
    return tasks

# core assembly

def combine_picture_description_streams(subject_id: str, task_order=None):
    subject_folder = os.path.join(DATA_DIRECTORY, subject_id)
    trans = load_transcriptions(subject_folder)
    durs  = load_audio_durations(subject_folder)

    if task_order is None:
        task_order = PICTURE_TASKS  # fallback to fixed order if not provided

    combined_audio = AudioSegment.silent(duration=0)
    total_offset = 0.0
    tasks_included, words_blocks, text_fallbacks = [], [], []

    for task in task_order:
        wav = load_audio_file(subject_folder, task)
        if wav is None:
            continue

        seg = AudioSegment.from_wav(wav)
        dur_audio = len(seg) / 1000.0
        d = durs[durs["task"] == task]["duration"].values
        dur = max(float(d[0]), dur_audio) if len(d) else dur_audio

        wdf = load_task_word_timestamps(subject_id, task)
        if wdf is not None and not wdf.empty:
            wdf2 = wdf.copy()
            wdf2["start"] = wdf2["start"].astype(float) + total_offset
            wdf2["end"]   = wdf2["end"].astype(float) + total_offset
            words_blocks.append(wdf2)
        else:
            t = trans[trans["task"] == task]["text_google"].values
            if len(t) and isinstance(t[0], str) and t[0].strip():
                text_fallbacks.append(t[0].strip())

        combined_audio += seg
        total_offset += dur
        tasks_included.append(task)

    combined_words = pd.concat(words_blocks, ignore_index=True) if words_blocks else None
    if combined_words is not None and not combined_words.empty:
        combined_text = " ".join(combined_words["word"].tolist())
    else:
        combined_text = " ".join(text_fallbacks).strip()

    if not combined_text:
        return None, None, 0.0, [], None

    return combined_text, combined_audio, total_offset, tasks_included, combined_words

def truncate_by_seconds(combined_text, combined_audio, combined_words, cap_seconds):
    if cap_seconds is None:
        return combined_text, combined_audio, combined_words
    ms = int(cap_seconds * 1000)
    audio_cut = combined_audio[:ms]
    if combined_words is not None and not combined_words.empty:
        kept = combined_words[combined_words["end"] <= cap_seconds].copy()
        text_cut = " ".join(kept["word"].tolist())
        return text_cut, audio_cut, kept
    return combined_text, audio_cut, None

def compute_features_for_slice(subject_id: str, text: str, audio_cut: AudioSegment, words_cut: pd.DataFrame | None):
    # lexica
    concreteness_lexicon = load_concreteness_lexicon()
    aoa_lexicon = load_aoa_lexicon()
    frequency_lexicon = load_frequency_norms()
    familiarity_lexicon = load_familiarity_norms()
    imageability_lexicon = load_imageability_norms()

    used_dur = len(audio_cut) / 1000.0

    feats = {
        "Subject_ID": subject_id,
        "duration_used_sec": used_dur,
        "n_words": n_words(text),
        "ttr": ttr(text),
        "average_word_length": avg_word_length(text),
        "filler_word_ratio": filler_word_ratio(text),
        "brunets_index": brunets_index(text),
        "honores_statistic": honores_statistic(text),
        "guirauds_statistic": guirauds_statistic(text),
        "light_verb_ratio": light_verb_ratio(text),
        "empty_word_ratio": empty_word_ratio(text),
        "nid_ratio": nid_ratio(text),
        "adjacent_repetitions": adjacent_repetitions(text),
    }
    feats.update(mattr(text, window_sizes=[10,20,30,40,50]))
    feats.update(pos_ratios_spacy(text))
    feats.update(calculate_fluency_features(text))

    for name, lex in [
        ("aoa",  aoa_lexicon),
        ("fam",  familiarity_lexicon),
        ("img",  imageability_lexicon),
        ("freq", frequency_lexicon),
        ("concr",concreteness_lexicon),
    ]:
        feats[f"{name}_nouns"]   = compute_avg_by_pos(text, lex, ["NOUN"])
        feats[f"{name}_verbs"]   = compute_avg_by_pos(text, lex, ["VERB"])
        feats[f"{name}_content"] = compute_avg_by_pos(text, lex, ["NOUN","VERB","ADJ"])

    feats.update(extract_acoustic_features(audio_segment=audio_cut, text=text, duration=used_dur))
    feats.update(extract_egemaps(audio_segment=audio_cut))

    # article_pause_contentword on CUT timestamps (if available)
    if words_cut is not None and not words_cut.empty:
        with tempfile.NamedTemporaryFile(suffix=".csv", delete=False) as tmpf:
            tmp_path = tmpf.name
        words_cut[["word","start","end"]].to_csv(tmp_path, index=False)
        try:
            apc = article_pause_contentword(tmp_path)
        except Exception:
            apc = None
        finally:
            try:
                os.remove(tmp_path)
            except Exception:
                pass
        feats["article_pause_contentword"] = apc
    else:
        feats["article_pause_contentword"] = None

    return pd.DataFrame([feats])

# run

def main():
    os.makedirs(OUT_DIR, exist_ok=True)
    CKPT_DIR = os.path.join(OUT_DIR, "_checkpoints")
    os.makedirs(CKPT_DIR, exist_ok=True)

    subjects = sorted([
        s for s in os.listdir(DATA_DIRECTORY)
        if os.path.isdir(os.path.join(DATA_DIRECTORY, s)) and s.isdigit()
    ], key=lambda x: int(x))

    # load processed sets from checkpoints if present; else from existing CSVs
    processed = {}
    for fname in OUTPUTS.keys():
        ckpt_path = os.path.join(CKPT_DIR, fname + ".json")
        done = load_checkpoint(ckpt_path)
        if not done:
            out_path = os.path.join(OUT_DIR, fname)
            if os.path.exists(out_path):
                try:
                    dfp = pd.read_csv(out_path, usecols=["Subject_ID"])
                    done = set(dfp["Subject_ID"].astype(str))
                except Exception:
                    done = set()
        processed[fname] = done

    for sid in subjects:
        subj_folder = os.path.join(DATA_DIRECTORY, sid)
        if not any(os.path.exists(os.path.join(subj_folder, f"{t}.wav")) for t in PICTURE_TASKS):
            print(f"[skip] {sid}: no picture-description audio")
            continue

        # reproducible per-subject randomized order
        task_order = task_order_for_subject(sid)

        combo = combine_picture_description_streams(sid, task_order=task_order)
        if combo[3] == []:
            print(f"[skip] {sid}: no picture-description data")
            continue
        combined_text, combined_audio, _total, _tasks_included, combined_words = combo

        # compute once, then reuse for each cap/file
        for fname, cap in OUTPUTS.items():
            out_path = os.path.join(OUT_DIR, fname)
            ckpt_path = os.path.join(CKPT_DIR, fname + ".json")

            if sid in processed[fname]:
                print(f"[{fname}] already processed {sid}, skipping")
                continue

            print(f"[{fname}] processing {sid} (cap={cap}s)")
            text_cut, audio_cut, words_cut = truncate_by_seconds(
                combined_text, combined_audio, combined_words, cap
            )

            try:
                df_slice = compute_features_for_slice(
                    sid, text=text_cut, audio_cut=audio_cut, words_cut=words_cut
                )
                # audit columns for order effects
                df_slice["first_task"] = _tasks_included[0] if _tasks_included else None
                df_slice["task_order"] = "|".join(_tasks_included) if _tasks_included else None

                append_row_atomic(out_path, df_slice)
                processed[fname].add(sid)
                save_checkpoint(ckpt_path, processed[fname])
            except Exception as e:
                print(f"[{fname}] ERROR {sid}: {e}")
                continue

    print("\ndone. wrote/updated:")
    for fname in OUTPUTS.keys():
        print(" -", os.path.join(OUT_DIR, fname))

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package words to /Users/gilanorup/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [picture_description.csv] processing 41 (cap=300s)
# [picture_description_1min.csv] processing 41 (cap=60s)
# [picture_description_2min.csv] processing 41 (cap=120s)
# [picture_description.csv] processing 43 (cap=300s)
# [picture_description_1min.csv] processing 43 (cap=60s)
# [picture_description_2min.csv] processing 43 (cap=120s)
# [picture_description.csv] processing 44 (cap=300s)
# [picture_description_1min.csv] processing 44 (cap=60s)
# [picture_description_2min.csv] processing 44 (cap=120s)
# [picture_description.csv] processing 46 (cap=300s)
# [picture_description_1min.csv] processing 46 (cap=60s)
# [picture_description_2min.csv] processing 46 (cap=120s)
# [picture_description.csv] processing 49 (cap=300s)
# [picture_description_1min.csv] processing 49 (cap=60s)
# [picture_description_2min.csv] processing 49 (cap=120s)
# [picture_description.csv] processing 50 (cap=300s)
# [picture_description_1min.csv] processing 50 (cap=60s)
# [picture_description_2min.csv] processing 50 (cap=120s)
# [picture_description.csv] processing 54 (cap=300s)
# [picture_description_1min.csv] processing 54 (cap=60s)
# [picture_description_2min.csv] processing 54 (cap=120s)
# [picture_description.csv] processing 56 (cap=300s)
# [picture_description_1min.csv] processing 56 (cap=60s)
# [picture_description_2min.csv] processing 56 (cap=120s)
# [picture_description.csv] processing 59 (cap=300s)
# [picture_description_1min.csv] processing 59 (cap=60s)
# [picture_description_2min.csv] processing 59 (cap=120s)
# [picture_description.csv] processing 61 (cap=300s)
# [picture_description_1min.csv] processing 61 (cap=60s)
# [picture_description_2min.csv] processing 61 (cap=120s)
# [picture_description.csv] processing 83 (cap=300s)
# [picture_description_1min.csv] processing 83 (cap=60s)
# [picture_description_2min.csv] processing 83 (cap=120s)
# [picture_description.csv] processing 84 (cap=300s)
# [picture_description_1min.csv] processing 84 (cap=60s)
# [picture_description_2min.csv] processing 84 (cap=120s)
# [picture_description.csv] processing 85 (cap=300s)
# [picture_description_1min.csv] processing 85 (cap=60s)
# [picture_description_2min.csv] processing 85 (cap=120s)
# [picture_description.csv] processing 86 (cap=300s)
# [picture_description_1min.csv] processing 86 (cap=60s)
# [picture_description_2min.csv] processing 86 (cap=120s)
# [picture_description.csv] processing 88 (cap=300s)
# [picture_description_1min.csv] processing 88 (cap=60s)
# [picture_description_2min.csv] processing 88 (cap=120s)
# [picture_description.csv] processing 89 (cap=300s)
# [picture_description_1min.csv] processing 89 (cap=60s)
# [picture_description_2min.csv] processing 89 (cap=120s)
# [picture_description.csv] processing 90 (cap=300s)
# [picture_description_1min.csv] processing 90 (cap=60s)
# [picture_description_2min.csv] processing 90 (cap=120s)
# [picture_description.csv] processing 91 (cap=300s)
# [picture_description_1min.csv] processing 91 (cap=60s)
# [picture_description_2min.csv] processing 91 (cap=120s)
# [picture_description.csv] processing 92 (cap=300s)
# [picture_description_1min.csv] processing 92 (cap=60s)
# [picture_description_2min.csv] processing 92 (cap=120s)
# [picture_description.csv] processing 93 (cap=300s)
# [picture_description_1min.csv] processing 93 (cap=60s)
# [picture_description_2min.csv] processing 93 (cap=120s)
# [picture_description.csv] processing 97 (cap=300s)
# [picture_description_1min.csv] processing 97 (cap=60s)
# [picture_description_2min.csv] processing 97 (cap=120s)
# [picture_description.csv] processing 98 (cap=300s)
# [picture_description_1min.csv] processing 98 (cap=60s)
# [picture_description_2min.csv] processing 98 (cap=120s)
# [picture_description.csv] processing 99 (cap=300s)
# [picture_description_1min.csv] processing 99 (cap=60s)
# [picture_description_2min.csv] processing 99 (cap=120s)
# [picture_description.csv] processing 101 (cap=300s)
# [picture_description_1min.csv] processing 101 (cap=60s)
# [picture_description_2min.csv] processing 101 (cap=120s)
# [picture_description.csv] processing 102 (cap=300s)
# [picture_description_1min.csv] processing 102 (cap=60s)
# [picture_description_2min.csv] processing 102 (cap=120s)
# [picture_description.csv] processing 103 (cap=300s)
# [picture_description_1min.csv] processing 103 (cap=60s)
# [picture_description_2min.csv] processing 103 (cap=120s)
# [picture_description.csv] processing 104 (cap=300s)
# [picture_description_1min.csv] processing 104 (cap=60s)
# [picture_description_2min.csv] processing 104 (cap=120s)
# [picture_description.csv] processing 105 (cap=300s)
# [picture_description_1min.csv] processing 105 (cap=60s)
# [picture_description_2min.csv] processing 105 (cap=120s)
# [picture_description.csv] processing 107 (cap=300s)
# [picture_description_1min.csv] processing 107 (cap=60s)
# [picture_description_2min.csv] processing 107 (cap=120s)
# [picture_description.csv] processing 109 (cap=300s)
# [picture_description_1min.csv] processing 109 (cap=60s)
# [picture_description_2min.csv] processing 109 (cap=120s)
# [picture_description.csv] processing 110 (cap=300s)
# [picture_description_1min.csv] processing 110 (cap=60s)
# [picture_description_2min.csv] processing 110 (cap=120s)
# [picture_description.csv] processing 111 (cap=300s)
# [picture_description_1min.csv] processing 111 (cap=60s)
# [picture_description_2min.csv] processing 111 (cap=120s)
# [picture_description.csv] processing 112 (cap=300s)
# [picture_description_1min.csv] processing 112 (cap=60s)
# [picture_description_2min.csv] processing 112 (cap=120s)
# [picture_description.csv] processing 115 (cap=300s)
# [picture_description_1min.csv] processing 115 (cap=60s)
# [picture_description_2min.csv] processing 115 (cap=120s)
# [picture_description.csv] processing 119 (cap=300s)
# [picture_description_1min.csv] processing 119 (cap=60s)
# [picture_description_2min.csv] processing 119 (cap=120s)
# [picture_description.csv] processing 120 (cap=300s)
# [picture_description_1min.csv] processing 120 (cap=60s)
# [picture_description_2min.csv] processing 120 (cap=120s)
# [picture_description.csv] processing 122 (cap=300s)
# [picture_description_1min.csv] processing 122 (cap=60s)
# [picture_description_2min.csv] processing 122 (cap=120s)
# [picture_description.csv] processing 123 (cap=300s)
# [picture_description_1min.csv] processing 123 (cap=60s)
# [picture_description_2min.csv] processing 123 (cap=120s)
# [picture_description.csv] processing 124 (cap=300s)
# [picture_description_1min.csv] processing 124 (cap=60s)
# [picture_description_2min.csv] processing 124 (cap=120s)
# [picture_description.csv] processing 127 (cap=300s)
# [picture_description_1min.csv] processing 127 (cap=60s)
# [picture_description_2min.csv] processing 127 (cap=120s)
# [picture_description.csv] processing 128 (cap=300s)
# [picture_description_1min.csv] processing 128 (cap=60s)
# [picture_description_2min.csv] processing 128 (cap=120s)
# [picture_description.csv] processing 129 (cap=300s)
# [picture_description_1min.csv] processing 129 (cap=60s)
# [picture_description_2min.csv] processing 129 (cap=120s)
# [picture_description.csv] processing 130 (cap=300s)
# [picture_description_1min.csv] processing 130 (cap=60s)
# [picture_description_2min.csv] processing 130 (cap=120s)
# [picture_description.csv] processing 132 (cap=300s)
# [picture_description_1min.csv] processing 132 (cap=60s)
# [picture_description_2min.csv] processing 132 (cap=120s)
# [picture_description.csv] processing 133 (cap=300s)
# [picture_description_1min.csv] processing 133 (cap=60s)
# [picture_description_2min.csv] processing 133 (cap=120s)
# [picture_description.csv] processing 134 (cap=300s)
# [picture_description_1min.csv] processing 134 (cap=60s)
# [picture_description_2min.csv] processing 134 (cap=120s)
# [picture_description.csv] processing 135 (cap=300s)
# [picture_description_1min.csv] processing 135 (cap=60s)
# [picture_description_2min.csv] processing 135 (cap=120s)
# [picture_description.csv] processing 136 (cap=300s)
# [picture_description_1min.csv] processing 136 (cap=60s)
# [picture_description_2min.csv] processing 136 (cap=120s)
# [picture_description.csv] processing 137 (cap=300s)
# [picture_description_1min.csv] processing 137 (cap=60s)
# [picture_description_2min.csv] processing 137 (cap=120s)
# [picture_description.csv] processing 138 (cap=300s)
# [picture_description_1min.csv] processing 138 (cap=60s)
# [picture_description_2min.csv] processing 138 (cap=120s)
# [picture_description.csv] processing 139 (cap=300s)
# [picture_description_1min.csv] processing 139 (cap=60s)
# [picture_description_2min.csv] processing 139 (cap=120s)
# [picture_description.csv] processing 140 (cap=300s)
# [picture_description_1min.csv] processing 140 (cap=60s)
# [picture_description_2min.csv] processing 140 (cap=120s)
# [picture_description.csv] processing 141 (cap=300s)
# [picture_description_1min.csv] processing 141 (cap=60s)
# [picture_description_2min.csv] processing 141 (cap=120s)
# [picture_description.csv] processing 142 (cap=300s)
# [picture_description_1min.csv] processing 142 (cap=60s)
# [picture_description_2min.csv] processing 142 (cap=120s)
# [picture_description.csv] processing 143 (cap=300s)
# [picture_description_1min.csv] processing 143 (cap=60s)
# [picture_description_2min.csv] processing 143 (cap=120s)
# [picture_description.csv] processing 145 (cap=300s)
# [picture_description_1min.csv] processing 145 (cap=60s)
# [picture_description_2min.csv] processing 145 (cap=120s)
# [picture_description.csv] processing 146 (cap=300s)
# [picture_description_1min.csv] processing 146 (cap=60s)
# [picture_description_2min.csv] processing 146 (cap=120s)
# [picture_description.csv] processing 147 (cap=300s)
# [picture_description_1min.csv] processing 147 (cap=60s)
# [picture_description_2min.csv] processing 147 (cap=120s)
# [picture_description.csv] processing 149 (cap=300s)
# [picture_description_1min.csv] processing 149 (cap=60s)
# [picture_description_2min.csv] processing 149 (cap=120s)
# [picture_description.csv] processing 150 (cap=300s)
# [picture_description_1min.csv] processing 150 (cap=60s)
# [picture_description_2min.csv] processing 150 (cap=120s)
# [picture_description.csv] processing 151 (cap=300s)
# [picture_description_1min.csv] processing 151 (cap=60s)
# [picture_description_2min.csv] processing 151 (cap=120s)
# [picture_description.csv] processing 152 (cap=300s)
# [picture_description_1min.csv] processing 152 (cap=60s)
# [picture_description_2min.csv] processing 152 (cap=120s)
# [picture_description.csv] processing 153 (cap=300s)
# [picture_description_1min.csv] processing 153 (cap=60s)
# [picture_description_2min.csv] processing 153 (cap=120s)
# [picture_description.csv] processing 154 (cap=300s)
# [picture_description_1min.csv] processing 154 (cap=60s)
# [picture_description_2min.csv] processing 154 (cap=120s)
# [picture_description.csv] processing 157 (cap=300s)
# [picture_description_1min.csv] processing 157 (cap=60s)
# [picture_description_2min.csv] processing 157 (cap=120s)
# [picture_description.csv] processing 158 (cap=300s)
# [picture_description_1min.csv] processing 158 (cap=60s)
# [picture_description_2min.csv] processing 158 (cap=120s)
# [picture_description.csv] processing 160 (cap=300s)
# [picture_description_1min.csv] processing 160 (cap=60s)
# [picture_description_2min.csv] processing 160 (cap=120s)
# [picture_description.csv] processing 162 (cap=300s)
# [picture_description_1min.csv] processing 162 (cap=60s)
# [picture_description_2min.csv] processing 162 (cap=120s)
# [picture_description.csv] processing 163 (cap=300s)
# [picture_description_1min.csv] processing 163 (cap=60s)
# [picture_description_2min.csv] processing 163 (cap=120s)
# [picture_description.csv] processing 165 (cap=300s)
# [picture_description_1min.csv] processing 165 (cap=60s)
# [picture_description_2min.csv] processing 165 (cap=120s)
# [picture_description.csv] processing 169 (cap=300s)
# [picture_description_1min.csv] processing 169 (cap=60s)
# [picture_description_2min.csv] processing 169 (cap=120s)
# [picture_description.csv] processing 170 (cap=300s)
# [picture_description_1min.csv] processing 170 (cap=60s)
# [picture_description_2min.csv] processing 170 (cap=120s)
# [picture_description.csv] processing 172 (cap=300s)
# [picture_description_1min.csv] processing 172 (cap=60s)
# [picture_description_2min.csv] processing 172 (cap=120s)
# [picture_description.csv] processing 173 (cap=300s)
# [picture_description_1min.csv] processing 173 (cap=60s)
# [picture_description_2min.csv] processing 173 (cap=120s)
# [picture_description.csv] processing 174 (cap=300s)
# [picture_description_1min.csv] processing 174 (cap=60s)
# [picture_description_2min.csv] processing 174 (cap=120s)
# [picture_description.csv] processing 175 (cap=300s)
# [picture_description_1min.csv] processing 175 (cap=60s)
# [picture_description_2min.csv] processing 175 (cap=120s)
# [picture_description.csv] processing 176 (cap=300s)
# [picture_description_1min.csv] processing 176 (cap=60s)
# [picture_description_2min.csv] processing 176 (cap=120s)
# [picture_description.csv] processing 177 (cap=300s)
# [picture_description_1min.csv] processing 177 (cap=60s)
# [picture_description_2min.csv] processing 177 (cap=120s)
# [picture_description.csv] processing 179 (cap=300s)
# [picture_description_1min.csv] processing 179 (cap=60s)
# [picture_description_2min.csv] processing 179 (cap=120s)
# [picture_description.csv] processing 183 (cap=300s)
# [picture_description_1min.csv] processing 183 (cap=60s)
# [picture_description_2min.csv] processing 183 (cap=120s)
# [picture_description.csv] processing 184 (cap=300s)
# [picture_description_1min.csv] processing 184 (cap=60s)
# [picture_description_2min.csv] processing 184 (cap=120s)
# [picture_description.csv] processing 185 (cap=300s)
# [picture_description_1min.csv] processing 185 (cap=60s)
# [picture_description_2min.csv] processing 185 (cap=120s)
# [picture_description.csv] processing 186 (cap=300s)
# [picture_description_1min.csv] processing 186 (cap=60s)
# [picture_description_2min.csv] processing 186 (cap=120s)
# [picture_description.csv] processing 188 (cap=300s)
# [picture_description_1min.csv] processing 188 (cap=60s)
# [picture_description_2min.csv] processing 188 (cap=120s)
# [picture_description.csv] processing 189 (cap=300s)
# [picture_description_1min.csv] processing 189 (cap=60s)
# [picture_description_2min.csv] processing 189 (cap=120s)
# [picture_description.csv] processing 190 (cap=300s)
# [picture_description_1min.csv] processing 190 (cap=60s)
# [picture_description_2min.csv] processing 190 (cap=120s)
# [picture_description.csv] processing 193 (cap=300s)
# [picture_description_1min.csv] processing 193 (cap=60s)
# [picture_description_2min.csv] processing 193 (cap=120s)
# [picture_description.csv] processing 195 (cap=300s)
# [picture_description_1min.csv] processing 195 (cap=60s)
# [picture_description_2min.csv] processing 195 (cap=120s)
# [picture_description.csv] processing 196 (cap=300s)
# [picture_description_1min.csv] processing 196 (cap=60s)
# [picture_description_2min.csv] processing 196 (cap=120s)
# [picture_description.csv] processing 197 (cap=300s)
# [picture_description_1min.csv] processing 197 (cap=60s)
# [picture_description_2min.csv] processing 197 (cap=120s)
# [picture_description.csv] processing 198 (cap=300s)
# [picture_description_1min.csv] processing 198 (cap=60s)
# [picture_description_2min.csv] processing 198 (cap=120s)
# [picture_description.csv] processing 199 (cap=300s)
# [picture_description_1min.csv] processing 199 (cap=60s)
# [picture_description_2min.csv] processing 199 (cap=120s)
# [picture_description.csv] processing 200 (cap=300s)
# [picture_description_1min.csv] processing 200 (cap=60s)
# [picture_description_2min.csv] processing 200 (cap=120s)
# [picture_description.csv] processing 201 (cap=300s)
# [picture_description_1min.csv] processing 201 (cap=60s)
# [picture_description_2min.csv] processing 201 (cap=120s)
# [picture_description.csv] processing 202 (cap=300s)
# [picture_description_1min.csv] processing 202 (cap=60s)
# [picture_description_2min.csv] processing 202 (cap=120s)
# [picture_description.csv] processing 203 (cap=300s)
# [picture_description_1min.csv] processing 203 (cap=60s)
# [picture_description_2min.csv] processing 203 (cap=120s)
# [picture_description.csv] processing 204 (cap=300s)
# [picture_description_1min.csv] processing 204 (cap=60s)
# [picture_description_2min.csv] processing 204 (cap=120s)
# [picture_description.csv] processing 205 (cap=300s)
# [picture_description_1min.csv] processing 205 (cap=60s)
# [picture_description_2min.csv] processing 205 (cap=120s)
# [picture_description.csv] processing 206 (cap=300s)
# [picture_description_1min.csv] processing 206 (cap=60s)
# [picture_description_2min.csv] processing 206 (cap=120s)
# [picture_description.csv] processing 207 (cap=300s)
# [picture_description_1min.csv] processing 207 (cap=60s)
# [picture_description_2min.csv] processing 207 (cap=120s)
# [picture_description.csv] processing 208 (cap=300s)
# [picture_description_1min.csv] processing 208 (cap=60s)
# [picture_description_2min.csv] processing 208 (cap=120s)
# [picture_description.csv] processing 209 (cap=300s)
# [picture_description_1min.csv] processing 209 (cap=60s)
# [picture_description_2min.csv] processing 209 (cap=120s)
# [picture_description.csv] processing 210 (cap=300s)
# [picture_description_1min.csv] processing 210 (cap=60s)
# [picture_description_2min.csv] processing 210 (cap=120s)
# [picture_description.csv] processing 211 (cap=300s)
# [picture_description_1min.csv] processing 211 (cap=60s)
# [picture_description_2min.csv] processing 211 (cap=120s)
# [picture_description.csv] processing 212 (cap=300s)
# [picture_description_1min.csv] processing 212 (cap=60s)
# [picture_description_2min.csv] processing 212 (cap=120s)
# [picture_description.csv] processing 213 (cap=300s)
# [picture_description_1min.csv] processing 213 (cap=60s)
# [picture_description_2min.csv] processing 213 (cap=120s)
# [picture_description.csv] processing 214 (cap=300s)
# [picture_description_1min.csv] processing 214 (cap=60s)
# [picture_description_2min.csv] processing 214 (cap=120s)
# [picture_description.csv] processing 215 (cap=300s)
# [picture_description_1min.csv] processing 215 (cap=60s)
# [picture_description_2min.csv] processing 215 (cap=120s)
# [picture_description.csv] processing 216 (cap=300s)
# [picture_description_1min.csv] processing 216 (cap=60s)
# [picture_description_2min.csv] processing 216 (cap=120s)
# [picture_description.csv] processing 217 (cap=300s)
# [picture_description_1min.csv] processing 217 (cap=60s)
# [picture_description_2min.csv] processing 217 (cap=120s)
# [picture_description.csv] processing 218 (cap=300s)
# [picture_description_1min.csv] processing 218 (cap=60s)
# [picture_description_2min.csv] processing 218 (cap=120s)
# [picture_description.csv] processing 219 (cap=300s)
# [picture_description_1min.csv] processing 219 (cap=60s)
# [picture_description_2min.csv] processing 219 (cap=120s)
# [picture_description.csv] processing 220 (cap=300s)
# [picture_description_1min.csv] processing 220 (cap=60s)
# [picture_description_2min.csv] processing 220 (cap=120s)
# [picture_description.csv] processing 222 (cap=300s)
# [picture_description_1min.csv] processing 222 (cap=60s)
# [picture_description_2min.csv] processing 222 (cap=120s)
# [picture_description.csv] processing 224 (cap=300s)
# [picture_description_1min.csv] processing 224 (cap=60s)
# [picture_description_2min.csv] processing 224 (cap=120s)
# [picture_description.csv] processing 225 (cap=300s)
# [picture_description_1min.csv] processing 225 (cap=60s)
# [picture_description_2min.csv] processing 225 (cap=120s)
# [picture_description.csv] processing 226 (cap=300s)
# [picture_description_1min.csv] processing 226 (cap=60s)
# [picture_description_2min.csv] processing 226 (cap=120s)
# [picture_description.csv] processing 228 (cap=300s)
# [picture_description_1min.csv] processing 228 (cap=60s)
# [picture_description_2min.csv] processing 228 (cap=120s)
# [picture_description.csv] processing 229 (cap=300s)
# [picture_description_1min.csv] processing 229 (cap=60s)
# [picture_description_2min.csv] processing 229 (cap=120s)
# [picture_description.csv] processing 230 (cap=300s)
# [picture_description_1min.csv] processing 230 (cap=60s)
# [picture_description_2min.csv] processing 230 (cap=120s)
# [picture_description.csv] processing 232 (cap=300s)
# [picture_description_1min.csv] processing 232 (cap=60s)
# [picture_description_2min.csv] processing 232 (cap=120s)
# [picture_description.csv] processing 233 (cap=300s)
# [picture_description_1min.csv] processing 233 (cap=60s)
# [picture_description_2min.csv] processing 233 (cap=120s)
# [picture_description.csv] processing 234 (cap=300s)
# [picture_description_1min.csv] processing 234 (cap=60s)
# [picture_description_2min.csv] processing 234 (cap=120s)
# [picture_description.csv] processing 237 (cap=300s)
# [picture_description_1min.csv] processing 237 (cap=60s)
# [picture_description_2min.csv] processing 237 (cap=120s)
# [picture_description.csv] processing 239 (cap=300s)
# [picture_description_1min.csv] processing 239 (cap=60s)
# [picture_description_2min.csv] processing 239 (cap=120s)
# [picture_description.csv] processing 241 (cap=300s)
# [picture_description_1min.csv] processing 241 (cap=60s)
# [picture_description_2min.csv] processing 241 (cap=120s)
# [picture_description.csv] processing 242 (cap=300s)
# [picture_description_1min.csv] processing 242 (cap=60s)
# [picture_description_2min.csv] processing 242 (cap=120s)
# [picture_description.csv] processing 243 (cap=300s)
# [picture_description_1min.csv] processing 243 (cap=60s)
# [picture_description_2min.csv] processing 243 (cap=120s)
# [picture_description.csv] processing 244 (cap=300s)
# [picture_description_1min.csv] processing 244 (cap=60s)
# [picture_description_2min.csv] processing 244 (cap=120s)
# [picture_description.csv] processing 247 (cap=300s)
# [picture_description_1min.csv] processing 247 (cap=60s)
# [picture_description_2min.csv] processing 247 (cap=120s)
# [picture_description.csv] processing 248 (cap=300s)
# [picture_description_1min.csv] processing 248 (cap=60s)
# [picture_description_2min.csv] processing 248 (cap=120s)
# [picture_description.csv] processing 249 (cap=300s)
# [picture_description_1min.csv] processing 249 (cap=60s)
# [picture_description_2min.csv] processing 249 (cap=120s)
# [picture_description.csv] processing 250 (cap=300s)
# [picture_description_1min.csv] processing 250 (cap=60s)
# [picture_description_2min.csv] processing 250 (cap=120s)
# [picture_description.csv] processing 251 (cap=300s)
# [picture_description_1min.csv] processing 251 (cap=60s)
# [picture_description_2min.csv] processing 251 (cap=120s)
# [picture_description.csv] processing 252 (cap=300s)
# [picture_description_1min.csv] processing 252 (cap=60s)
# [picture_description_2min.csv] processing 252 (cap=120s)
# [picture_description.csv] processing 253 (cap=300s)
# [picture_description_1min.csv] processing 253 (cap=60s)
# [picture_description_2min.csv] processing 253 (cap=120s)
# [picture_description.csv] processing 254 (cap=300s)
# [picture_description_1min.csv] processing 254 (cap=60s)
# [picture_description_2min.csv] processing 254 (cap=120s)
# [picture_description.csv] processing 257 (cap=300s)
# [picture_description_1min.csv] processing 257 (cap=60s)
# [picture_description_2min.csv] processing 257 (cap=120s)
# [picture_description.csv] processing 258 (cap=300s)
# [picture_description_1min.csv] processing 258 (cap=60s)
# [picture_description_2min.csv] processing 258 (cap=120s)
# [picture_description.csv] processing 260 (cap=300s)
# [picture_description_1min.csv] processing 260 (cap=60s)
# [picture_description_2min.csv] processing 260 (cap=120s)
# [picture_description.csv] processing 261 (cap=300s)
# [picture_description_1min.csv] processing 261 (cap=60s)
# [picture_description_2min.csv] processing 261 (cap=120s)
# [picture_description.csv] processing 262 (cap=300s)
# [picture_description_1min.csv] processing 262 (cap=60s)
# [picture_description_2min.csv] processing 262 (cap=120s)
# [picture_description.csv] processing 263 (cap=300s)
# [picture_description_1min.csv] processing 263 (cap=60s)
# [picture_description_2min.csv] processing 263 (cap=120s)
# [picture_description.csv] processing 264 (cap=300s)
# [picture_description_1min.csv] processing 264 (cap=60s)
# [picture_description_2min.csv] processing 264 (cap=120s)
# [picture_description.csv] processing 266 (cap=300s)
# [picture_description_1min.csv] processing 266 (cap=60s)
# [picture_description_2min.csv] processing 266 (cap=120s)
# [picture_description.csv] processing 267 (cap=300s)
# [picture_description_1min.csv] processing 267 (cap=60s)
# [picture_description_2min.csv] processing 267 (cap=120s)
# [picture_description.csv] processing 268 (cap=300s)
# [picture_description_1min.csv] processing 268 (cap=60s)
# [picture_description_2min.csv] processing 268 (cap=120s)
# [picture_description.csv] processing 269 (cap=300s)
# [picture_description_1min.csv] processing 269 (cap=60s)
# [picture_description_2min.csv] processing 269 (cap=120s)
# [picture_description.csv] processing 270 (cap=300s)
# [picture_description_1min.csv] processing 270 (cap=60s)
# [picture_description_2min.csv] processing 270 (cap=120s)
# [picture_description.csv] processing 271 (cap=300s)
# [picture_description_1min.csv] processing 271 (cap=60s)
# [picture_description_2min.csv] processing 271 (cap=120s)
# [picture_description.csv] processing 272 (cap=300s)
# [picture_description_1min.csv] processing 272 (cap=60s)
# [picture_description_2min.csv] processing 272 (cap=120s)
# [picture_description.csv] processing 274 (cap=300s)
# [picture_description_1min.csv] processing 274 (cap=60s)
# [picture_description_2min.csv] processing 274 (cap=120s)
# [picture_description.csv] processing 275 (cap=300s)
# [picture_description_1min.csv] processing 275 (cap=60s)
# [picture_description_2min.csv] processing 275 (cap=120s)
# [picture_description.csv] processing 276 (cap=300s)
# [picture_description_1min.csv] processing 276 (cap=60s)
# [picture_description_2min.csv] processing 276 (cap=120s)
# [picture_description.csv] processing 277 (cap=300s)
# [picture_description_1min.csv] processing 277 (cap=60s)
# [picture_description_2min.csv] processing 277 (cap=120s)
# [picture_description.csv] processing 278 (cap=300s)
# [picture_description_1min.csv] processing 278 (cap=60s)
# [picture_description_2min.csv] processing 278 (cap=120s)
# [picture_description.csv] processing 279 (cap=300s)
# [picture_description_1min.csv] processing 279 (cap=60s)
# [picture_description_2min.csv] processing 279 (cap=120s)
# [picture_description.csv] processing 282 (cap=300s)
# [picture_description_1min.csv] processing 282 (cap=60s)
# [picture_description_2min.csv] processing 282 (cap=120s)
# [picture_description.csv] processing 283 (cap=300s)
# [picture_description_1min.csv] processing 283 (cap=60s)
# [picture_description_2min.csv] processing 283 (cap=120s)
# [picture_description.csv] processing 284 (cap=300s)
# [picture_description_1min.csv] processing 284 (cap=60s)
# [picture_description_2min.csv] processing 284 (cap=120s)
# [picture_description.csv] processing 288 (cap=300s)
# [picture_description_1min.csv] processing 288 (cap=60s)
# [picture_description_2min.csv] processing 288 (cap=120s)
# [picture_description.csv] processing 289 (cap=300s)
# [picture_description_1min.csv] processing 289 (cap=60s)
# [picture_description_2min.csv] processing 289 (cap=120s)
# [picture_description.csv] processing 290 (cap=300s)
# [picture_description_1min.csv] processing 290 (cap=60s)
# [picture_description_2min.csv] processing 290 (cap=120s)
# [picture_description.csv] processing 291 (cap=300s)
# [picture_description_1min.csv] processing 291 (cap=60s)
# [picture_description_2min.csv] processing 291 (cap=120s)
# [picture_description.csv] processing 292 (cap=300s)
# [picture_description_1min.csv] processing 292 (cap=60s)
# [picture_description_2min.csv] processing 292 (cap=120s)
# [picture_description.csv] processing 293 (cap=300s)
# [picture_description_1min.csv] processing 293 (cap=60s)
# [picture_description_2min.csv] processing 293 (cap=120s)
# [picture_description.csv] processing 294 (cap=300s)
# [picture_description_1min.csv] processing 294 (cap=60s)
# [picture_description_2min.csv] processing 294 (cap=120s)
# [picture_description.csv] processing 295 (cap=300s)
# [picture_description_1min.csv] processing 295 (cap=60s)
# [picture_description_2min.csv] processing 295 (cap=120s)
# [picture_description.csv] processing 297 (cap=300s)
# [picture_description_1min.csv] processing 297 (cap=60s)
# [picture_description_2min.csv] processing 297 (cap=120s)
# [picture_description.csv] processing 298 (cap=300s)
# [picture_description_1min.csv] processing 298 (cap=60s)
# [picture_description_2min.csv] processing 298 (cap=120s)
# [picture_description.csv] processing 300 (cap=300s)
# [picture_description_1min.csv] processing 300 (cap=60s)
# [picture_description_2min.csv] processing 300 (cap=120s)
# [picture_description.csv] processing 301 (cap=300s)
# [picture_description_1min.csv] processing 301 (cap=60s)
# [picture_description_2min.csv] processing 301 (cap=120s)
# [picture_description.csv] processing 303 (cap=300s)
# [picture_description_1min.csv] processing 303 (cap=60s)
# [picture_description_2min.csv] processing 303 (cap=120s)
# [picture_description.csv] processing 304 (cap=300s)
# [picture_description_1min.csv] processing 304 (cap=60s)
# [picture_description_2min.csv] processing 304 (cap=120s)
# [picture_description.csv] processing 305 (cap=300s)
# [picture_description_1min.csv] processing 305 (cap=60s)
# [picture_description_2min.csv] processing 305 (cap=120s)
# [picture_description.csv] processing 306 (cap=300s)
# [picture_description_1min.csv] processing 306 (cap=60s)
# [picture_description_2min.csv] processing 306 (cap=120s)
# [picture_description.csv] processing 311 (cap=300s)
# [picture_description_1min.csv] processing 311 (cap=60s)
# [picture_description_2min.csv] processing 311 (cap=120s)
# [picture_description.csv] processing 312 (cap=300s)
# [picture_description_1min.csv] processing 312 (cap=60s)
# [picture_description_2min.csv] processing 312 (cap=120s)
# [picture_description.csv] processing 314 (cap=300s)
# [picture_description_1min.csv] processing 314 (cap=60s)
# [picture_description_2min.csv] processing 314 (cap=120s)
# [picture_description.csv] processing 315 (cap=300s)
# [picture_description_1min.csv] processing 315 (cap=60s)
# [picture_description_2min.csv] processing 315 (cap=120s)
# [picture_description.csv] processing 318 (cap=300s)
# [picture_description_1min.csv] processing 318 (cap=60s)
# [picture_description_2min.csv] processing 318 (cap=120s)
# [picture_description.csv] processing 319 (cap=300s)
# [picture_description_1min.csv] processing 319 (cap=60s)
# [picture_description_2min.csv] processing 319 (cap=120s)
# [picture_description.csv] processing 321 (cap=300s)
# [picture_description_1min.csv] processing 321 (cap=60s)
# [picture_description_2min.csv] processing 321 (cap=120s)
# [picture_description.csv] processing 322 (cap=300s)
# [picture_description_1min.csv] processing 322 (cap=60s)
# [picture_description_2min.csv] processing 322 (cap=120s)
# [picture_description.csv] processing 324 (cap=300s)
# [picture_description_1min.csv] processing 324 (cap=60s)
# [picture_description_2min.csv] processing 324 (cap=120s)
# [picture_description.csv] processing 325 (cap=300s)
# [picture_description_1min.csv] processing 325 (cap=60s)
# [picture_description_2min.csv] processing 325 (cap=120s)
# [picture_description.csv] processing 326 (cap=300s)
# [picture_description_1min.csv] processing 326 (cap=60s)
# [picture_description_2min.csv] processing 326 (cap=120s)
# [picture_description.csv] processing 327 (cap=300s)
# [picture_description_1min.csv] processing 327 (cap=60s)
# [picture_description_2min.csv] processing 327 (cap=120s)
# [picture_description.csv] processing 328 (cap=300s)
# [picture_description_1min.csv] processing 328 (cap=60s)
# [picture_description_2min.csv] processing 328 (cap=120s)
# [picture_description.csv] processing 329 (cap=300s)
# [picture_description_1min.csv] processing 329 (cap=60s)
# [picture_description_2min.csv] processing 329 (cap=120s)
# [picture_description.csv] processing 330 (cap=300s)
# [picture_description_1min.csv] processing 330 (cap=60s)
# [picture_description_2min.csv] processing 330 (cap=120s)
# [picture_description.csv] processing 331 (cap=300s)
# [picture_description_1min.csv] processing 331 (cap=60s)
# [picture_description_2min.csv] processing 331 (cap=120s)
# [picture_description.csv] processing 335 (cap=300s)
# [picture_description_1min.csv] processing 335 (cap=60s)
# [picture_description_2min.csv] processing 335 (cap=120s)
# [picture_description.csv] processing 336 (cap=300s)
# [picture_description_1min.csv] processing 336 (cap=60s)
# [picture_description_2min.csv] processing 336 (cap=120s)
# [picture_description.csv] processing 337 (cap=300s)
# [picture_description_1min.csv] processing 337 (cap=60s)
# [picture_description_2min.csv] processing 337 (cap=120s)
# [picture_description.csv] processing 338 (cap=300s)
# [picture_description_1min.csv] processing 338 (cap=60s)
# [picture_description_2min.csv] processing 338 (cap=120s)
# [picture_description.csv] processing 339 (cap=300s)
# [picture_description_1min.csv] processing 339 (cap=60s)
# [picture_description_2min.csv] processing 339 (cap=120s)
# [picture_description.csv] processing 341 (cap=300s)
# [picture_description_1min.csv] processing 341 (cap=60s)
# [picture_description_2min.csv] processing 341 (cap=120s)
# [picture_description.csv] processing 342 (cap=300s)
# [picture_description_1min.csv] processing 342 (cap=60s)
# [picture_description_2min.csv] processing 342 (cap=120s)
# [picture_description.csv] processing 343 (cap=300s)
# [picture_description_1min.csv] processing 343 (cap=60s)
# [picture_description_2min.csv] processing 343 (cap=120s)
# [picture_description.csv] processing 344 (cap=300s)
# [picture_description_1min.csv] processing 344 (cap=60s)
# [picture_description_2min.csv] processing 344 (cap=120s)
# [picture_description.csv] processing 345 (cap=300s)
# [picture_description_1min.csv] processing 345 (cap=60s)
# [picture_description_2min.csv] processing 345 (cap=120s)
# [picture_description.csv] processing 346 (cap=300s)
# [picture_description_1min.csv] processing 346 (cap=60s)
# [picture_description_2min.csv] processing 346 (cap=120s)
# [picture_description.csv] processing 347 (cap=300s)
# [picture_description_1min.csv] processing 347 (cap=60s)
# [picture_description_2min.csv] processing 347 (cap=120s)
# [picture_description.csv] processing 348 (cap=300s)
# [picture_description_1min.csv] processing 348 (cap=60s)
# [picture_description_2min.csv] processing 348 (cap=120s)
# [picture_description.csv] processing 349 (cap=300s)
# [picture_description_1min.csv] processing 349 (cap=60s)
# [picture_description_2min.csv] processing 349 (cap=120s)
# [picture_description.csv] processing 354 (cap=300s)
# [picture_description_1min.csv] processing 354 (cap=60s)
# [picture_description_2min.csv] processing 354 (cap=120s)
# [picture_description.csv] processing 355 (cap=300s)
# [picture_description_1min.csv] processing 355 (cap=60s)
# [picture_description_2min.csv] processing 355 (cap=120s)
# [picture_description.csv] processing 356 (cap=300s)
# [picture_description_1min.csv] processing 356 (cap=60s)
# [picture_description_2min.csv] processing 356 (cap=120s)
# [picture_description.csv] processing 357 (cap=300s)
# [picture_description_1min.csv] processing 357 (cap=60s)
# [picture_description_2min.csv] processing 357 (cap=120s)
# [picture_description.csv] processing 358 (cap=300s)
# [picture_description_1min.csv] processing 358 (cap=60s)
# [picture_description_2min.csv] processing 358 (cap=120s)
# [picture_description.csv] processing 359 (cap=300s)
# [picture_description_1min.csv] processing 359 (cap=60s)
# [picture_description_2min.csv] processing 359 (cap=120s)
# [picture_description.csv] processing 360 (cap=300s)
# [picture_description_1min.csv] processing 360 (cap=60s)
# [picture_description_2min.csv] processing 360 (cap=120s)
# [picture_description.csv] processing 361 (cap=300s)
# [picture_description_1min.csv] processing 361 (cap=60s)
# [picture_description_2min.csv] processing 361 (cap=120s)
# [picture_description.csv] processing 362 (cap=300s)
# [picture_description_1min.csv] processing 362 (cap=60s)
# [picture_description_2min.csv] processing 362 (cap=120s)
# [picture_description.csv] processing 363 (cap=300s)
# [picture_description_1min.csv] processing 363 (cap=60s)
# [picture_description_2min.csv] processing 363 (cap=120s)
# [picture_description.csv] processing 364 (cap=300s)
# [picture_description_1min.csv] processing 364 (cap=60s)
# [picture_description_2min.csv] processing 364 (cap=120s)
# [picture_description.csv] processing 365 (cap=300s)
# [picture_description_1min.csv] processing 365 (cap=60s)
# [picture_description_2min.csv] processing 365 (cap=120s)
# [picture_description.csv] processing 366 (cap=300s)
# [picture_description_1min.csv] processing 366 (cap=60s)
# [picture_description_2min.csv] processing 366 (cap=120s)
# [picture_description.csv] processing 367 (cap=300s)
# [picture_description_1min.csv] processing 367 (cap=60s)
# [picture_description_2min.csv] processing 367 (cap=120s)
# [picture_description.csv] processing 368 (cap=300s)
# [picture_description_1min.csv] processing 368 (cap=60s)
# [picture_description_2min.csv] processing 368 (cap=120s)
# [picture_description.csv] processing 369 (cap=300s)
# [picture_description_1min.csv] processing 369 (cap=60s)
# [picture_description_2min.csv] processing 369 (cap=120s)
# [picture_description.csv] processing 371 (cap=300s)
# [picture_description_1min.csv] processing 371 (cap=60s)
# [picture_description_2min.csv] processing 371 (cap=120s)
# [picture_description.csv] processing 372 (cap=300s)
# [picture_description_1min.csv] processing 372 (cap=60s)
# [picture_description_2min.csv] processing 372 (cap=120s)
# [picture_description.csv] processing 373 (cap=300s)
# [picture_description_1min.csv] processing 373 (cap=60s)
# [picture_description_2min.csv] processing 373 (cap=120s)
# [picture_description.csv] processing 374 (cap=300s)
# [picture_description_1min.csv] processing 374 (cap=60s)
# [picture_description_2min.csv] processing 374 (cap=120s)
# [picture_description.csv] processing 375 (cap=300s)
# [picture_description_1min.csv] processing 375 (cap=60s)
# [picture_description_2min.csv] processing 375 (cap=120s)
# [picture_description.csv] processing 376 (cap=300s)
# [picture_description_1min.csv] processing 376 (cap=60s)
# [picture_description_2min.csv] processing 376 (cap=120s)
# [picture_description.csv] processing 377 (cap=300s)
# [picture_description_1min.csv] processing 377 (cap=60s)
# [picture_description_2min.csv] processing 377 (cap=120s)
# [picture_description.csv] processing 378 (cap=300s)
# [picture_description_1min.csv] processing 378 (cap=60s)
# [picture_description_2min.csv] processing 378 (cap=120s)
# [picture_description.csv] processing 379 (cap=300s)
# [picture_description_1min.csv] processing 379 (cap=60s)
# [picture_description_2min.csv] processing 379 (cap=120s)
# [picture_description.csv] processing 381 (cap=300s)
# [picture_description_1min.csv] processing 381 (cap=60s)
# [picture_description_2min.csv] processing 381 (cap=120s)
# [picture_description.csv] processing 382 (cap=300s)
# [picture_description_1min.csv] processing 382 (cap=60s)
# [picture_description_2min.csv] processing 382 (cap=120s)
# [picture_description.csv] processing 384 (cap=300s)
# [picture_description_1min.csv] processing 384 (cap=60s)
# [picture_description_2min.csv] processing 384 (cap=120s)
# [picture_description.csv] processing 385 (cap=300s)
# [picture_description_1min.csv] processing 385 (cap=60s)
# [picture_description_2min.csv] processing 385 (cap=120s)
# [picture_description.csv] processing 386 (cap=300s)
# [picture_description_1min.csv] processing 386 (cap=60s)
# [picture_description_2min.csv] processing 386 (cap=120s)
# [picture_description.csv] processing 387 (cap=300s)
# [picture_description_1min.csv] processing 387 (cap=60s)
# [picture_description_2min.csv] processing 387 (cap=120s)
# [picture_description.csv] processing 388 (cap=300s)
# [picture_description_1min.csv] processing 388 (cap=60s)
# [picture_description_2min.csv] processing 388 (cap=120s)
# [picture_description.csv] processing 389 (cap=300s)
# [picture_description_1min.csv] processing 389 (cap=60s)
# [picture_description_2min.csv] processing 389 (cap=120s)
# [picture_description.csv] processing 390 (cap=300s)
# [picture_description_1min.csv] processing 390 (cap=60s)
# [picture_description_2min.csv] processing 390 (cap=120s)
# [picture_description.csv] processing 392 (cap=300s)
# [picture_description_1min.csv] processing 392 (cap=60s)
# [picture_description_2min.csv] processing 392 (cap=120s)
# [picture_description.csv] processing 393 (cap=300s)
# [picture_description_1min.csv] processing 393 (cap=60s)
# [picture_description_2min.csv] processing 393 (cap=120s)
# [picture_description.csv] processing 394 (cap=300s)
# [picture_description_1min.csv] processing 394 (cap=60s)
# [picture_description_2min.csv] processing 394 (cap=120s)
# [picture_description.csv] processing 395 (cap=300s)
# [picture_description_1min.csv] processing 395 (cap=60s)
# [picture_description_2min.csv] processing 395 (cap=120s)
# [picture_description.csv] processing 396 (cap=300s)
# [picture_description_1min.csv] processing 396 (cap=60s)
# [picture_description_2min.csv] processing 396 (cap=120s)
# [picture_description.csv] processing 397 (cap=300s)
# [picture_description_1min.csv] processing 397 (cap=60s)
# [picture_description_2min.csv] processing 397 (cap=120s)
# [picture_description.csv] processing 399 (cap=300s)
# [picture_description_1min.csv] processing 399 (cap=60s)
# [picture_description_2min.csv] processing 399 (cap=120s)
# [picture_description.csv] processing 400 (cap=300s)
# [picture_description_1min.csv] processing 400 (cap=60s)
# [picture_description_2min.csv] processing 400 (cap=120s)
# [picture_description.csv] processing 401 (cap=300s)
# [picture_description_1min.csv] processing 401 (cap=60s)
# [picture_description_2min.csv] processing 401 (cap=120s)
# [picture_description.csv] processing 402 (cap=300s)
# [picture_description_1min.csv] processing 402 (cap=60s)
# [picture_description_2min.csv] processing 402 (cap=120s)
# [picture_description.csv] processing 403 (cap=300s)
# [picture_description_1min.csv] processing 403 (cap=60s)
# [picture_description_2min.csv] processing 403 (cap=120s)
# [picture_description.csv] processing 404 (cap=300s)
# [picture_description_1min.csv] processing 404 (cap=60s)
# [picture_description_2min.csv] processing 404 (cap=120s)
# [picture_description.csv] processing 406 (cap=300s)
# [picture_description_1min.csv] processing 406 (cap=60s)
# [picture_description_2min.csv] processing 406 (cap=120s)
# [picture_description.csv] processing 407 (cap=300s)
# [picture_description_1min.csv] processing 407 (cap=60s)
# [picture_description_2min.csv] processing 407 (cap=120s)
# [picture_description.csv] processing 409 (cap=300s)
# [picture_description_1min.csv] processing 409 (cap=60s)
# [picture_description_2min.csv] processing 409 (cap=120s)
# [picture_description.csv] processing 410 (cap=300s)
# [picture_description_1min.csv] processing 410 (cap=60s)
# [picture_description_2min.csv] processing 410 (cap=120s)
# [picture_description.csv] processing 411 (cap=300s)
# [picture_description_1min.csv] processing 411 (cap=60s)
# [picture_description_2min.csv] processing 411 (cap=120s)
# [picture_description.csv] processing 415 (cap=300s)
# [picture_description_1min.csv] processing 415 (cap=60s)
# [picture_description_2min.csv] processing 415 (cap=120s)
# [picture_description.csv] processing 416 (cap=300s)
# [picture_description_1min.csv] processing 416 (cap=60s)
# [picture_description_2min.csv] processing 416 (cap=120s)
# [picture_description.csv] processing 417 (cap=300s)
# [picture_description_1min.csv] processing 417 (cap=60s)
# [picture_description_2min.csv] processing 417 (cap=120s)
# [picture_description.csv] processing 419 (cap=300s)
# [picture_description_1min.csv] processing 419 (cap=60s)
# [picture_description_2min.csv] processing 419 (cap=120s)
# [picture_description.csv] processing 420 (cap=300s)
# [picture_description_1min.csv] processing 420 (cap=60s)
# [picture_description_2min.csv] processing 420 (cap=120s)
# [picture_description.csv] processing 421 (cap=300s)
# [picture_description_1min.csv] processing 421 (cap=60s)
# [picture_description_2min.csv] processing 421 (cap=120s)
# [picture_description.csv] processing 423 (cap=300s)
# [picture_description_1min.csv] processing 423 (cap=60s)
# [picture_description_2min.csv] processing 423 (cap=120s)
# [picture_description.csv] processing 424 (cap=300s)
# [picture_description_1min.csv] processing 424 (cap=60s)
# [picture_description_2min.csv] processing 424 (cap=120s)
# [picture_description.csv] processing 425 (cap=300s)
# [picture_description_1min.csv] processing 425 (cap=60s)
# [picture_description_2min.csv] processing 425 (cap=120s)
# [picture_description.csv] processing 427 (cap=300s)
# [picture_description_1min.csv] processing 427 (cap=60s)
# [picture_description_2min.csv] processing 427 (cap=120s)
# [picture_description.csv] processing 428 (cap=300s)
# [picture_description_1min.csv] processing 428 (cap=60s)
# [picture_description_2min.csv] processing 428 (cap=120s)
# [picture_description.csv] processing 429 (cap=300s)
# [picture_description_1min.csv] processing 429 (cap=60s)
# [picture_description_2min.csv] processing 429 (cap=120s)
# [picture_description.csv] processing 430 (cap=300s)
# [picture_description_1min.csv] processing 430 (cap=60s)
# [picture_description_2min.csv] processing 430 (cap=120s)
# [picture_description.csv] processing 431 (cap=300s)
# [picture_description_1min.csv] processing 431 (cap=60s)
# [picture_description_2min.csv] processing 431 (cap=120s)
# [picture_description.csv] processing 432 (cap=300s)
# [picture_description_1min.csv] processing 432 (cap=60s)
# [picture_description_2min.csv] processing 432 (cap=120s)
# [picture_description.csv] processing 433 (cap=300s)
# [picture_description_1min.csv] processing 433 (cap=60s)
# [picture_description_2min.csv] processing 433 (cap=120s)
# [picture_description.csv] processing 434 (cap=300s)
# [picture_description_1min.csv] processing 434 (cap=60s)
# [picture_description_2min.csv] processing 434 (cap=120s)
# [picture_description.csv] processing 436 (cap=300s)
# [picture_description_1min.csv] processing 436 (cap=60s)
# [picture_description_2min.csv] processing 436 (cap=120s)
# [picture_description.csv] processing 437 (cap=300s)
# [picture_description_1min.csv] processing 437 (cap=60s)
# [picture_description_2min.csv] processing 437 (cap=120s)
# [picture_description.csv] processing 438 (cap=300s)
# [picture_description_1min.csv] processing 438 (cap=60s)
# [picture_description_2min.csv] processing 438 (cap=120s)
# [picture_description.csv] processing 439 (cap=300s)
# [picture_description_1min.csv] processing 439 (cap=60s)
# [picture_description_2min.csv] processing 439 (cap=120s)
# [picture_description.csv] processing 441 (cap=300s)
# [picture_description_1min.csv] processing 441 (cap=60s)
# [picture_description_2min.csv] processing 441 (cap=120s)
# [picture_description.csv] processing 443 (cap=300s)
# [picture_description_1min.csv] processing 443 (cap=60s)
# [picture_description_2min.csv] processing 443 (cap=120s)
# [picture_description.csv] processing 444 (cap=300s)
# [picture_description_1min.csv] processing 444 (cap=60s)
# [picture_description_2min.csv] processing 444 (cap=120s)
# [picture_description.csv] processing 445 (cap=300s)
# [picture_description_1min.csv] processing 445 (cap=60s)
# [picture_description_2min.csv] processing 445 (cap=120s)
# [picture_description.csv] processing 446 (cap=300s)
# [picture_description_1min.csv] processing 446 (cap=60s)
# [picture_description_2min.csv] processing 446 (cap=120s)
# [picture_description.csv] processing 447 (cap=300s)
# [picture_description_1min.csv] processing 447 (cap=60s)
# [picture_description_2min.csv] processing 447 (cap=120s)
# [picture_description.csv] processing 448 (cap=300s)
# [picture_description_1min.csv] processing 448 (cap=60s)
# [picture_description_2min.csv] processing 448 (cap=120s)
# [picture_description.csv] processing 449 (cap=300s)
# [picture_description_1min.csv] processing 449 (cap=60s)
# [picture_description_2min.csv] processing 449 (cap=120s)
# [picture_description.csv] processing 450 (cap=300s)
# [picture_description_1min.csv] processing 450 (cap=60s)
# [picture_description_2min.csv] processing 450 (cap=120s)
# [picture_description.csv] processing 451 (cap=300s)
# [picture_description_1min.csv] processing 451 (cap=60s)
# [picture_description_2min.csv] processing 451 (cap=120s)
# [picture_description.csv] processing 454 (cap=300s)
# [picture_description_1min.csv] processing 454 (cap=60s)
# [picture_description_2min.csv] processing 454 (cap=120s)
# [picture_description.csv] processing 455 (cap=300s)
# [picture_description_1min.csv] processing 455 (cap=60s)
# [picture_description_2min.csv] processing 455 (cap=120s)
# [picture_description.csv] processing 459 (cap=300s)
# ...
# [picture_description.csv] processing 1245 (cap=300s)
# [picture_description_1min.csv] processing 1245 (cap=60s)
# [picture_description_2min.csv] processing 1245 (cap=120s)
# [picture_description.csv] processing 1246 (cap=300s)
# [picture_description_1min.csv] processing 1246 (cap=60s)
# [picture_description_2min.csv] processing 1246 (cap=120s)
# [picture_description.csv] processing 1247 (cap=300s)
# [picture_description_1min.csv] processing 1247 (cap=60s)
# [picture_description_2min.csv] processing 1247 (cap=120s)
# [picture_description.csv] processing 1248 (cap=300s)
# [picture_description_1min.csv] processing 1248 (cap=60s)
# [picture_description_2min.csv] processing 1248 (cap=120s)
# [picture_description.csv] processing 1249 (cap=300s)
# [picture_description_1min.csv] processing 1249 (cap=60s)
# [picture_description_2min.csv] processing 1249 (cap=120s)
# [picture_description.csv] processing 1250 (cap=300s)
# [picture_description_1min.csv] processing 1250 (cap=60s)
# [picture_description_2min.csv] processing 1250 (cap=120s)
# [picture_description.csv] processing 1251 (cap=300s)
# [picture_description_1min.csv] processing 1251 (cap=60s)
# [picture_description_2min.csv] processing 1251 (cap=120s)
# [picture_description.csv] processing 1252 (cap=300s)
# [picture_description_1min.csv] processing 1252 (cap=60s)
# [picture_description_2min.csv] processing 1252 (cap=120s)
# [picture_description.csv] processing 1253 (cap=300s)
# [picture_description_1min.csv] processing 1253 (cap=60s)
# [picture_description_2min.csv] processing 1253 (cap=120s)
# [picture_description.csv] processing 1254 (cap=300s)
# [picture_description_1min.csv] processing 1254 (cap=60s)
# [picture_description_2min.csv] processing 1254 (cap=120s)
# [picture_description.csv] processing 1255 (cap=300s)
# [picture_description_1min.csv] processing 1255 (cap=60s)
# [picture_description_2min.csv] processing 1255 (cap=120s)
# [picture_description.csv] processing 1257 (cap=300s)
# [picture_description_1min.csv] processing 1257 (cap=60s)
# [picture_description_2min.csv] processing 1257 (cap=120s)
# [picture_description.csv] processing 1258 (cap=300s)
# [picture_description_1min.csv] processing 1258 (cap=60s)
# [picture_description_2min.csv] processing 1258 (cap=120s)
# [picture_description.csv] processing 1264 (cap=300s)
# [picture_description_1min.csv] processing 1264 (cap=60s)
# [picture_description_2min.csv] processing 1264 (cap=120s)
# [picture_description.csv] processing 1266 (cap=300s)
# [picture_description_1min.csv] processing 1266 (cap=60s)
# [picture_description_2min.csv] processing 1266 (cap=120s)
# [picture_description.csv] processing 1267 (cap=300s)
# [picture_description_1min.csv] processing 1267 (cap=60s)
# [picture_description_2min.csv] processing 1267 (cap=120s)
# [picture_description.csv] processing 1268 (cap=300s)
# [picture_description_1min.csv] processing 1268 (cap=60s)
# [picture_description_2min.csv] processing 1268 (cap=120s)
# [picture_description.csv] processing 1271 (cap=300s)
# [picture_description_1min.csv] processing 1271 (cap=60s)
# [picture_description_2min.csv] processing 1271 (cap=120s)
# [picture_description.csv] processing 1274 (cap=300s)
# [picture_description_1min.csv] processing 1274 (cap=60s)
# [picture_description_2min.csv] processing 1274 (cap=120s)
# [picture_description.csv] processing 1275 (cap=300s)
# [picture_description_1min.csv] processing 1275 (cap=60s)
# [picture_description_2min.csv] processing 1275 (cap=120s)
# [picture_description.csv] processing 1276 (cap=300s)
# [picture_description_1min.csv] processing 1276 (cap=60s)
# [picture_description_2min.csv] processing 1276 (cap=120s)
# [picture_description.csv] processing 1277 (cap=300s)
# [picture_description_1min.csv] processing 1277 (cap=60s)
# [picture_description_2min.csv] processing 1277 (cap=120s)
# [picture_description.csv] processing 1278 (cap=300s)
# [picture_description_1min.csv] processing 1278 (cap=60s)
# [picture_description_2min.csv] processing 1278 (cap=120s)
# [picture_description.csv] processing 1280 (cap=300s)
# [picture_description_1min.csv] processing 1280 (cap=60s)
# [picture_description_2min.csv] processing 1280 (cap=120s)
# [picture_description.csv] processing 1281 (cap=300s)
# [picture_description_1min.csv] processing 1281 (cap=60s)
# [picture_description_2min.csv] processing 1281 (cap=120s)
# [picture_description.csv] processing 1282 (cap=300s)
# [picture_description_1min.csv] processing 1282 (cap=60s)
# [picture_description_2min.csv] processing 1282 (cap=120s)
# [picture_description.csv] processing 1283 (cap=300s)
# [picture_description_1min.csv] processing 1283 (cap=60s)
# [picture_description_2min.csv] processing 1283 (cap=120s)
# [picture_description.csv] processing 1284 (cap=300s)
# [picture_description_1min.csv] processing 1284 (cap=60s)
# [picture_description_2min.csv] processing 1284 (cap=120s)
# [picture_description.csv] processing 1285 (cap=300s)
# [picture_description_1min.csv] processing 1285 (cap=60s)
# [picture_description_2min.csv] processing 1285 (cap=120s)
# [picture_description.csv] processing 1286 (cap=300s)
# [picture_description_1min.csv] processing 1286 (cap=60s)
# [picture_description_2min.csv] processing 1286 (cap=120s)
# [picture_description.csv] processing 1288 (cap=300s)
# [picture_description_1min.csv] processing 1288 (cap=60s)
# [picture_description_2min.csv] processing 1288 (cap=120s)
# [picture_description.csv] processing 1290 (cap=300s)
# [picture_description_1min.csv] processing 1290 (cap=60s)
# [picture_description_2min.csv] processing 1290 (cap=120s)
# [picture_description.csv] processing 1291 (cap=300s)
# [picture_description_1min.csv] processing 1291 (cap=60s)
# [picture_description_2min.csv] processing 1291 (cap=120s)
# [picture_description.csv] processing 1292 (cap=300s)
# [picture_description_1min.csv] processing 1292 (cap=60s)
# [picture_description_2min.csv] processing 1292 (cap=120s)
# [picture_description.csv] processing 1293 (cap=300s)
# [picture_description_1min.csv] processing 1293 (cap=60s)
# [picture_description_2min.csv] processing 1293 (cap=120s)
# [picture_description.csv] processing 1294 (cap=300s)
# [picture_description_1min.csv] processing 1294 (cap=60s)
# [picture_description_2min.csv] processing 1294 (cap=120s)
# [picture_description.csv] processing 1295 (cap=300s)
# [picture_description_1min.csv] processing 1295 (cap=60s)
# [picture_description_2min.csv] processing 1295 (cap=120s)
# [picture_description.csv] processing 1297 (cap=300s)
# [picture_description_1min.csv] processing 1297 (cap=60s)
# [picture_description_2min.csv] processing 1297 (cap=120s)
# [picture_description.csv] processing 1298 (cap=300s)
# [picture_description_1min.csv] processing 1298 (cap=60s)
# [picture_description_2min.csv] processing 1298 (cap=120s)
# [picture_description.csv] processing 1299 (cap=300s)
# [picture_description_1min.csv] processing 1299 (cap=60s)
# [picture_description_2min.csv] processing 1299 (cap=120s)
# [picture_description.csv] processing 1302 (cap=300s)
# [picture_description_1min.csv] processing 1302 (cap=60s)
# [picture_description_2min.csv] processing 1302 (cap=120s)
# [picture_description.csv] processing 1304 (cap=300s)
# [picture_description_1min.csv] processing 1304 (cap=60s)
# [picture_description_2min.csv] processing 1304 (cap=120s)
# [picture_description.csv] processing 1305 (cap=300s)
# [picture_description_1min.csv] processing 1305 (cap=60s)
# [picture_description_2min.csv] processing 1305 (cap=120s)
# [picture_description.csv] processing 1308 (cap=300s)
# [picture_description_1min.csv] processing 1308 (cap=60s)
# [picture_description_2min.csv] processing 1308 (cap=120s)
# [picture_description.csv] processing 1309 (cap=300s)
# [picture_description_1min.csv] processing 1309 (cap=60s)
# [picture_description_2min.csv] processing 1309 (cap=120s)
# [picture_description.csv] processing 1310 (cap=300s)
# [picture_description_1min.csv] processing 1310 (cap=60s)
# [picture_description_2min.csv] processing 1310 (cap=120s)
# [picture_description.csv] processing 1311 (cap=300s)
# [picture_description_1min.csv] processing 1311 (cap=60s)
# [picture_description_2min.csv] processing 1311 (cap=120s)
# [picture_description.csv] processing 1312 (cap=300s)
# [picture_description_1min.csv] processing 1312 (cap=60s)
# [picture_description_2min.csv] processing 1312 (cap=120s)
# [picture_description.csv] processing 1313 (cap=300s)
# [picture_description_1min.csv] processing 1313 (cap=60s)
# [picture_description_2min.csv] processing 1313 (cap=120s)
# [picture_description.csv] processing 1314 (cap=300s)
# [picture_description_1min.csv] processing 1314 (cap=60s)
# [picture_description_2min.csv] processing 1314 (cap=120s)
# [picture_description.csv] processing 1315 (cap=300s)
# [picture_description_1min.csv] processing 1315 (cap=60s)
# [picture_description_2min.csv] processing 1315 (cap=120s)
# [picture_description.csv] processing 1316 (cap=300s)
# [picture_description_1min.csv] processing 1316 (cap=60s)
# [picture_description_2min.csv] processing 1316 (cap=120s)
# [picture_description.csv] processing 1317 (cap=300s)
# [picture_description_1min.csv] processing 1317 (cap=60s)
# [picture_description_2min.csv] processing 1317 (cap=120s)
# [picture_description.csv] processing 1318 (cap=300s)
# [picture_description_1min.csv] processing 1318 (cap=60s)
# [picture_description_2min.csv] processing 1318 (cap=120s)
# [picture_description.csv] processing 1319 (cap=300s)
# [picture_description_1min.csv] processing 1319 (cap=60s)
# [picture_description_2min.csv] processing 1319 (cap=120s)
# [picture_description.csv] processing 1320 (cap=300s)
# [picture_description_1min.csv] processing 1320 (cap=60s)
# [picture_description_2min.csv] processing 1320 (cap=120s)
# [picture_description.csv] processing 1322 (cap=300s)
# [picture_description_1min.csv] processing 1322 (cap=60s)
# [picture_description_2min.csv] processing 1322 (cap=120s)
# [picture_description.csv] processing 1324 (cap=300s)
# [picture_description_1min.csv] processing 1324 (cap=60s)
# [picture_description_2min.csv] processing 1324 (cap=120s)
# [picture_description.csv] processing 1325 (cap=300s)
# [picture_description_1min.csv] processing 1325 (cap=60s)
# [picture_description_2min.csv] processing 1325 (cap=120s)
# [picture_description.csv] processing 1326 (cap=300s)
# [picture_description_1min.csv] processing 1326 (cap=60s)
# [picture_description_2min.csv] processing 1326 (cap=120s)
# [picture_description.csv] processing 1327 (cap=300s)
# [picture_description_1min.csv] processing 1327 (cap=60s)
# [picture_description_2min.csv] processing 1327 (cap=120s)
# [picture_description.csv] processing 1328 (cap=300s)
# [picture_description_1min.csv] processing 1328 (cap=60s)
# [picture_description_2min.csv] processing 1328 (cap=120s)
# [picture_description.csv] processing 1330 (cap=300s)
# [picture_description_1min.csv] processing 1330 (cap=60s)
# [picture_description_2min.csv] processing 1330 (cap=120s)
# [picture_description.csv] processing 1331 (cap=300s)
# [picture_description_1min.csv] processing 1331 (cap=60s)
# [picture_description_2min.csv] processing 1331 (cap=120s)
# [picture_description.csv] processing 1332 (cap=300s)
# [picture_description_1min.csv] processing 1332 (cap=60s)
# [picture_description_2min.csv] processing 1332 (cap=120s)
# [picture_description.csv] processing 1334 (cap=300s)
# [picture_description_1min.csv] processing 1334 (cap=60s)
# [picture_description_2min.csv] processing 1334 (cap=120s)
# [picture_description.csv] processing 1336 (cap=300s)
# [picture_description_1min.csv] processing 1336 (cap=60s)
# [picture_description_2min.csv] processing 1336 (cap=120s)
# [picture_description.csv] processing 1339 (cap=300s)
# [picture_description_1min.csv] processing 1339 (cap=60s)
# [picture_description_2min.csv] processing 1339 (cap=120s)
# [picture_description.csv] processing 1340 (cap=300s)
# [picture_description_1min.csv] processing 1340 (cap=60s)
# [picture_description_2min.csv] processing 1340 (cap=120s)
# [picture_description.csv] processing 1341 (cap=300s)
# [picture_description_1min.csv] processing 1341 (cap=60s)
# [picture_description_2min.csv] processing 1341 (cap=120s)
# [picture_description.csv] processing 1344 (cap=300s)
# [picture_description_1min.csv] processing 1344 (cap=60s)
# [picture_description_2min.csv] processing 1344 (cap=120s)
# [picture_description.csv] processing 1346 (cap=300s)
# [picture_description_1min.csv] processing 1346 (cap=60s)
# [picture_description_2min.csv] processing 1346 (cap=120s)
# [picture_description.csv] processing 1347 (cap=300s)
# [picture_description_1min.csv] processing 1347 (cap=60s)
# [picture_description_2min.csv] processing 1347 (cap=120s)
# [picture_description.csv] processing 1348 (cap=300s)
# [picture_description_1min.csv] processing 1348 (cap=60s)
# [picture_description_2min.csv] processing 1348 (cap=120s)
# [picture_description.csv] processing 1349 (cap=300s)
# [picture_description_1min.csv] processing 1349 (cap=60s)
# [picture_description_2min.csv] processing 1349 (cap=120s)
# [picture_description.csv] processing 1350 (cap=300s)
# [picture_description_1min.csv] processing 1350 (cap=60s)
# [picture_description_2min.csv] processing 1350 (cap=120s)
# [picture_description.csv] processing 1351 (cap=300s)
# [picture_description_1min.csv] processing 1351 (cap=60s)
# [picture_description_2min.csv] processing 1351 (cap=120s)
# [picture_description.csv] processing 1353 (cap=300s)
# [picture_description_1min.csv] processing 1353 (cap=60s)
# [picture_description_2min.csv] processing 1353 (cap=120s)
# [picture_description.csv] processing 1354 (cap=300s)
# [picture_description_1min.csv] processing 1354 (cap=60s)
# [picture_description_2min.csv] processing 1354 (cap=120s)
# [picture_description.csv] processing 1355 (cap=300s)
# [picture_description_1min.csv] processing 1355 (cap=60s)
# [picture_description_2min.csv] processing 1355 (cap=120s)
# [picture_description.csv] processing 1356 (cap=300s)
# [picture_description_1min.csv] processing 1356 (cap=60s)
# [picture_description_2min.csv] processing 1356 (cap=120s)
# [picture_description.csv] processing 1357 (cap=300s)
# [picture_description_1min.csv] processing 1357 (cap=60s)
# [picture_description_2min.csv] processing 1357 (cap=120s)
# [picture_description.csv] processing 1358 (cap=300s)
# [picture_description_1min.csv] processing 1358 (cap=60s)
# [picture_description_2min.csv] processing 1358 (cap=120s)
# [picture_description.csv] processing 1359 (cap=300s)
# [picture_description_1min.csv] processing 1359 (cap=60s)
# [picture_description_2min.csv] processing 1359 (cap=120s)
# [picture_description.csv] processing 1360 (cap=300s)
# [picture_description_1min.csv] processing 1360 (cap=60s)
# [picture_description_2min.csv] processing 1360 (cap=120s)
# [picture_description.csv] processing 1361 (cap=300s)
# [picture_description_1min.csv] processing 1361 (cap=60s)
# [picture_description_2min.csv] processing 1361 (cap=120s)
# [picture_description.csv] processing 1362 (cap=300s)
# [picture_description_1min.csv] processing 1362 (cap=60s)
# [picture_description_2min.csv] processing 1362 (cap=120s)
# [picture_description.csv] processing 1363 (cap=300s)
# [picture_description_1min.csv] processing 1363 (cap=60s)
# [picture_description_2min.csv] processing 1363 (cap=120s)
# [picture_description.csv] processing 1365 (cap=300s)
# [picture_description_1min.csv] processing 1365 (cap=60s)
# [picture_description_2min.csv] processing 1365 (cap=120s)
# [picture_description.csv] processing 1366 (cap=300s)
# [picture_description_1min.csv] processing 1366 (cap=60s)
# [picture_description_2min.csv] processing 1366 (cap=120s)
# [picture_description.csv] processing 1368 (cap=300s)
# [picture_description_1min.csv] processing 1368 (cap=60s)
# [picture_description_2min.csv] processing 1368 (cap=120s)
# [picture_description.csv] processing 1369 (cap=300s)
# [picture_description_1min.csv] processing 1369 (cap=60s)
# [picture_description_2min.csv] processing 1369 (cap=120s)
# [picture_description.csv] processing 1370 (cap=300s)
# [picture_description_1min.csv] processing 1370 (cap=60s)
# [picture_description_2min.csv] processing 1370 (cap=120s)
#
# Done. Wrote/updated:
#  - /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/picture_description.csv
#  - /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/picture_description_1min.csv
#  - /Users/gilanorup/Desktop/Studium/MSc/MA/code/masters_thesis_gn/results/features/picture_description_2min.csv
